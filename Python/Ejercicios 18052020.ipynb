# %%
#EJERCICIOS SCRAPING 18-05-2020
import requests
url = "https://elpais.com/"
request = requests.get(url)
request
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup as BS
import urllib
from urllib.request import urlopen

url = "https://elpais.com/"
html = urlopen(url)
print(html)
print(type(html))
soup = BS(html)
print(soup)
# Out:
# ...
# <class 'http.client.HTTPResponse'>
# <!DOCTYPE html>
# ...

# %%
elem = soup.find_all("a")
print(type(elem))
for i in range(5):
    print(elem[i])
# Out:
# <class 'bs4.element.ResultSet'>
# <a class="current" href="https://elpais.com/s/setEspana.html">esp</a>
# <a class="" href="https://elpais.com/s/setAmerica.html">ame</a>
# <a class="" href="https://elpais.com/s/setBrasil.html">bra</a>
# <a class="" href="https://elpais.com/s/setCat.html">cat</a>
# <a class="" href="https://elpais.com/s/setEnglish.html">eng</a>

# %%
elem = soup.find_all("a")
for i in elem:
    print(elem[-5:])
# Out:
# [<a href="https://www.prisa.com/es/info/politica-de-cookies-publi" rel="noopener noreferrer" target="_blank" title="Política cookies">Política cookies</a>, <a href="//elpais.com/estaticos/mapa-web/" rel="noopener noreferrer" target="_blank" title="Mapa">Mapa</a>, <a href="//elpais.com/suscripciones/" rel="noopener noreferrer" target="_blank" title="EL PAÍS en KIOSKOyMÁS">EL PAÍS en KIOSKOyMÁS</a>, <a href="//elpais.com/tag/listado/" rel="noopener noreferrer" target="_blank" title="Índice">Índice</a>, <a href="//servicios.elpais.com/rss/" rel="noopener noreferrer" target="_blank" title="RSS">RSS</a>]
# ...

# %%
elem = soup.find_all("a")
for i in range(len(elem)):#Esto es lo mismo que el anterior??
    print(elem[-5:])
# Out:
# [<a href="https://www.prisa.com/es/info/politica-de-cookies-publi" rel="noopener noreferrer" target="_blank" title="Política cookies">Política cookies</a>, <a href="//elpais.com/estaticos/mapa-web/" rel="noopener noreferrer" target="_blank" title="Mapa">Mapa</a>, <a href="//elpais.com/suscripciones/" rel="noopener noreferrer" target="_blank" title="EL PAÍS en KIOSKOyMÁS">EL PAÍS en KIOSKOyMÁS</a>, <a href="//elpais.com/tag/listado/" rel="noopener noreferrer" target="_blank" title="Índice">Índice</a>, <a href="//servicios.elpais.com/rss/" rel="noopener noreferrer" target="_blank" title="RSS">RSS</a>]
# ...

# %%
elem = soup.find_all("a")
for i in range(len(elem))[-5:]:
    print(elem[i])
# Out:
# <a href="https://www.prisa.com/es/info/politica-de-cookies-publi" rel="noopener noreferrer" target="_blank" title="Política cookies">Política cookies</a>
# <a href="//elpais.com/estaticos/mapa-web/" rel="noopener noreferrer" target="_blank" title="Mapa">Mapa</a>
# <a href="//elpais.com/suscripciones/" rel="noopener noreferrer" target="_blank" title="EL PAÍS en KIOSKOyMÁS">EL PAÍS en KIOSKOyMÁS</a>
# <a href="//elpais.com/tag/listado/" rel="noopener noreferrer" target="_blank" title="Índice">Índice</a>
# <a href="//servicios.elpais.com/rss/" rel="noopener noreferrer" target="_blank" title="RSS">RSS</a>

# %%
import random # https://docs.python.org/3/library/random.html
l = ["a", "b", "c"]
for i in range(5):
    random.choice(l)
# Out:
# 'c'

# %%
import random
from random import shuffle
elem = soup.find_all("a")
aleatorio_elem = random.shuffle(elem)
print(aleatorio_elem)
for i in range(len(aleatorio_elem))[-5:]:
    print(elem[i])
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-1f839fa521fc> in <module>
#       4 aleatorio_elem = random.shuffle(elem)
#       5 print(aleatorio_elem)
# ----> 6 for i in range(len(aleatorio_elem))[-5:]:
#       7     print(elem[i])
#
# TypeError: object of type 'NoneType' has no len()

# %%
import random
from random import shuffle
elem = soup.find_all("a")
ordeando_elem = sorted(elem)
print(aleatorio_elem)
for i in range(len(aleatorio_elem))[-5:]:
    print(elem[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-437aff0128cd> in <module>
#       2 from random import shuffle
#       3 elem = soup.find_all("a")
# ----> 4 ordeando_elem = sorted(elem)
#       5 print(aleatorio_elem)
#       6 for i in range(len(aleatorio_elem))[-5:]:
#
# TypeError: '<' not supported between instances of 'Tag' and 'Tag'

# %%
#Vas a libreria y no hay metodo para ordenar elem, ¿luego vas a builtin funcs?¿Cúal es el orden?
elem_ordenado = sorted(soup.find_all("a"))
for i in range(len(elem_ordenado)):#Le tengo que dar alguna clave para ordenarlo?¿Cuál es la key para ordenar un html?
    print(elem_ordenado[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-f646b0228ebc> in <module>
# ----> 1 elem_ordenado = sorted(soup.find_all("a"))
#       2 for i in range(len(elem_ordenado)):
#       3     print(elem_ordenado[i])
#
# TypeError: '<' not supported between instances of 'Tag' and 'Tag'

# %%
from bs4 import BeautifulSoup as BS
import urllib
from urllib.request import urlopen

url = "https://www.tecnicasa.net/promociones/823614891"
html = urlopen(url)
print(html)
print(type(html))
soup = BS(html)
print(soup)
# Out:
# ...
# <class 'http.client.HTTPResponse'>
# <!DOCTYPE html>
# <html lang="es"><head><meta charset="utf-8"/><title>Venta y alquiler de pisos en Badajoz | Tecnicasa.net</title><base href="/"/><meta content="width=device-width,initial-scale=1" name="viewport"/><link href="favicon.ico" rel="icon" type="image/x-icon"/><link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/><link href="https://fonts.googleapis.com/css?family=Montserrat:400,500,700" rel="stylesheet"/><link href="styles.45190e4f20c980db4ca6.bundle.css" rel="stylesheet"/></head><body><app-root></app-root><script src="inline.318b50c57b4eba3d437b.bundle.js" type="text/javascript"></script><script src="polyfills.98b5c43ab35999b30c16.bundle.js" type="text/javascript"></script><script src="scripts.ec17d636791d5daccd0a.bundle.js" type="text/javascript"></script><script src="main.a343131ec89bcbfee957.bundle.js" type="text/javascript"></script></body></html>

# %%
html = <mat-cell _ngcontent-c27="" class="mat-cell cdk-column-size mat-column-size ng-star-inserted" role="gridcell"> 161 m2</mat-cell>
soup = BS(html)
elem = soup.find_all("mat-cell")
for i in range(len(elem)):
    print(elem[i])
# Out:
#   File "<ipython-input-24-3995a8a06f4f>", line 1
#     html = <mat-cell _ngcontent-c27="" class="mat-cell cdk-column-size mat-column-size ng-star-inserted" role="gridcell"> 161 m2</mat-cell>
#            ^
# SyntaxError: invalid syntax

# %%
import inspect
import pandas
print(inspect.getsource(pandas.DataFrame))
# Out:
# class DataFrame(NDFrame):
#     """ Two-dimensional size-mutable, potentially heterogeneous tabular data
#     structure with labeled axes (rows and columns). Arithmetic operations
#     align on both row and column labels. Can be thought of as a dict-like
#     container for Series objects. The primary pandas data structure.
#
#     Parameters
#     ----------
#     data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#         Dict can contain Series, arrays, constants, or list-like objects
#
#         .. versionchanged :: 0.23.0
#            If data is a dict, argument order is maintained for Python 3.6
#            and later.
#
#     index : Index or array-like
#         Index to use for resulting frame. Will default to RangeIndex if
#         no indexing information part of input data and no index provided
#     columns : Index or array-like
#         Column labels to use for resulting frame. Will default to
# ...

# %%
import datetime
from datetime import date
dia_semana = datetime.date.today().strftime("%w")
print(dia_semana)
# Out:
# 1
