# %%
# Función para conectar con API
def get_oauth_token():
    http_obj = Http()
    url = "https://api.idealista.com/oauth/token"
    apikey= urllib.parse.quote_plus('zv3u0zzhv10ojbnnrzm1rhc4rnxpjcv5')
    secret= urllib.parse.quote_plus('L4z1zpuu1LKH')
    auth = base64.encode(apikey + ':' + secret)
    body = {'grant_type':'client_credentials'}
    headers = {'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8','Authorization' : 'Basic ' + auth}
    resp, content = request(url,method='POST',headers=headers, body=urllib.parse.urlencode(body))
    return content
get_oauth_token()

# %%
# Añadido guardado en texto
def get_oauth_token():
	http_obj = Http()
	url = "https://api.idealista.com/oauth/token"
	apikey= urllib.parse.quote_plus('zv3u0zzhv10ojbnnrzm1rhc4rnxpjcv5')
	secret= urllib.parse.quote_plus('L4z1zpuu1LKH')
	auth = base64.encode(apikey + ':' + secret)
	body = {'grant_type':'client_credentials'}
	headers = {'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8','Authorization' : 'Basic ' + auth}
	resp, content = http_obj.request(url,method='POST',headers=headers, body=urllib.parse.urlencode(body))
	#Escribir en TXT
	text_file = open("session_token.txt", "w")
	text_file.write(content.text)
	text_file.close()
	return content
get_oauth_token()

# %%
# Requests

# %%
import requests
# r = requests.get('https://api.github.com/user', auth=('user', 'pass'))
r = requests.get('https://www.google.es') #https://api.github.com/user
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=ISO-8859-1'

# %%
r.encoding
# Out:
# 'ISO-8859-1'

# %%
r.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="es"><head><meta content="Google.es permite acceder a la información mundial en castellano, catalán, gallego, euskara e inglés." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="juKV4jZYIT5TV02xsoWpfw==">(function(){window.google={kEI:\'IAK8XrOCLY2OlwT8u71w\',kEXPI:\'0,202123,3,4,1151616,5663,731,223,3656,1448,207,3204,10,1051,175,364,1499,576,210,31,383,246,5,1354,372,34,99,177,131,121,104,113,177,5,356,5,1218,405,413,3,161,417130,706742,1197789,102,258,78,329040,1294,12383,4855,32691,15248,861,19403,9287,9188,8384,4859,1361,9290,3024,4744,11033,1808,4020,978,7931,5297,2054,920,873,1217,2383,592,5391,315,724,11306,3221,4517,1399,1380,519,399,2277,8,3683,706,1165,114,2212,530,149,1103,840,517,1137,279,50,56,158,4100,109,203,1137,2,2063,606,1839,184,1777,520,1947,1018,1,1210,94,327,1284,16,2927,2247,473,1339,748,1039,3227,773,2072,7,4808,1,1259,8078,2663,641,2046,1,402,2459,1226,1406,56,3935,1274,108,3407,908,2,1493,420,1642,881,1251,265,1386,1510,2523,226,997,828,840,1337,1098,3,576,970,865,372,1640,538,1368,706,149,189,2837,475,1462,1027,28,2224,1992,606,1344,47,120,876,97,82,569,4,498,1030,17,616,3,1,2,2,2,298,1363,311,149,782,265,223,339,36,276,395,2,8,12,29,750,14,4,654,6,391,305,132,1379,468,142,841,118,799,126,4,136,689,382,131,206,1505,173,43,826,370,104,212,500,639,1822,323,39,43,114,305,54,228,170,865,174,250,14,11,471,296,100,3,136,80,389,752,190,1195,282,330,3198,5813761,3309,1802585,4194806,2801216,549,333,444,1,2,80,1,900,896,1,8,1,2,2551,1,748,141,59,736,563,1,4265,1,1,1,1,137,1,1193,1401,3,461,248,58,9,25,2,1,1,1,3,30,6,9,2,46,3389972,20572126\',kBL:\'914T\'};google.sn=\'webhp\';google.kHL=\'es\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var c;a&&(!a.getAttribute||!(c=a.getAttribute("eid")));)a=a.parentNode;return c||google.kEI};google.getLEI=function(a){for(var c=null;a&&(!a.getAttribute||!(c=a.getAttribute("leid")));)a=a.parentNode;return c};google.ml=function(){return null};google.time=function(){return Date.now()};google.log=function(a,c,b,d,g){if(b=google.logUrl(a,c,b,d,g)){a=new Image;var e=google.lc,f=google.li;e[f]=a;a.onerror=a.onload=a.onabort=function(){delete e[f]};google.vel&&google.vel.lu&&google.vel.lu(b);a.src=b;google.li=f+1}};google.logUrl=function(a,c,b,d,g){var e="",f=google.ls||"";b||-1!=c.search("&ei=")||(e="&ei="+google.getEI(d),-1==c.search("&lei=")&&(d=google.getLEI(d))&&(e+="&lei="+d));d="";!b&&google.cshid&&-1==c.search("&cshid=")&&"slh"!=a&&(d="&cshid="+google.cshid);b=b||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+c+e+f+"&zx="+google.time()+d;/^http:/i.test(b)&&"https:"==window.location.protocol&&(google.ml(Error("a"),!1,{src:b,glmm:1}),b="");return b};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);\nvar a=window.location,b=a.href.indexOf("#");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf("#")&&a.replace("/search?"+c.replace(/(^|&)fp=[^&]*/g,"")+"&cad=h")};</script><st ...

# %%
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-33-9c78734cbfe1> in <module>()
# ----> 1 r.json()
#
# c:\python36\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# c:\python36\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# c:\python36\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# c:\python36\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import requests
url = 'http://worldagnetwork.com/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
print(result.content.decode())
# Out:
# <!doctype html>
# <!--[if lt IE 7 ]><html class="no-js ie ie6" lang="en"> <![endif]-->
# <!--[if IE 7 ]><html class="no-js ie ie7" lang="en"> <![endif]-->
# <!--[if IE 8 ]><html class="no-js ie ie8" lang="en"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--><html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
# <title>Business, Technology and Policies in U.S. Agriculture.</title>
#
# <!--[if lt IE 9]>
#     <script src="https://html5shim.googlecode.com/svn/trunk/html5.js"></script>
# <![endif]-->
#
#
#
# <link rel="stylesheet" type="text/css" href="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/css/bootstrap/bootstrap.css?v=1">
# <link rel="stylesheet" type="text/css" href="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/css/font-awesome.css">
#
# <link rel="stylesheet" type="text/css" href="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/css/flexslider.css">
#
# <link rel="stylesheet" type="text/css" media="all" href="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/style.css?v=1489425217" />
#
# <!-- Jetpack Site Verification Tags -->
# <meta name="google-site-verification" content="Nzl7qyIUm3mwnRxfntdgRC9n8Tw36bXltDP6_Wqb_Rw" />
#
# <!-- This site is optimized with the Yoast SEO plugin v13.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta name="description" content="Agriculture news to provide insight into the business, technology, programs and people that will continue to feed the world for years to come."/>
# <meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1"/>
# <link rel="canonical" href="https://worldagnetwork.com/" />
# <meta property="og:locale" content="en_US" />
# <meta property="og:type" content="website" />
# <meta property="og:title" content="Business, Technology and Policies in U.S. Agriculture." />
# <meta property="og:description" content="Agriculture news to provide insight into the business, technology, programs and people that will continue to feed the world for years to come." />
# <meta property="og:url" content="https://worldagnetwork.com/" />
# <meta property="og:site_name" content="World Agriculture Network" />
# <meta name="twitter:card" content="summary" />
# <meta name="twitter:description" content="Agriculture news to provide insight into the business, technology, programs and people that will continue to feed the world for years to come." />
# <meta name="twitter:title" content="Business, Technology and Policies in U.S. Agriculture." />
# <meta name="twitter:site" content="@worldagnetwork" />
# <meta name="twitter:creator" content="@worldagnetwork" />
# <meta name="msvalidate.01" content="378E45255BBAA22F1BB9AE1FB5C7D277" />
# <script type='application/ld+json' class='yoast-schema-graph yoast-schema-graph--main'>{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://worldagnetwork.com/#website","url":"https://worldagnetwork.com/","name":"World Agriculture Network","inLanguage":"en-US","description":"A Network for the World of Agriculture and Farming","potentialAction":[{"@type":"SearchAction","target":"https://worldagnetwork.com/?s={search_term_string}","query-input":"required name=search_term_string"}]},{"@type":"WebPage","@id":"https://worldagnetwork.com/#webpage","url":"https://worldagnetwork.com/","name":"Business, Technology and Policies in U.S. Agriculture.","isPartOf":{"@id":"https://worldagnetwork.com/#website"},"inLanguage":"en-US","datePublished":"2013-08-05T13:49:12+00:00","dateModified":"2016-02-18T18:02:22+00:00","description":"Agriculture news to provide insight into the business, technology, programs and people that will continue to feed the world for years to come.","potentialAction":[{"@type":"ReadAction","target":["https://worldagnetwork.com/"]}]}]}</script>
# <!-- / Yoast SEO plugin. -->
#
# <link rel='dns-prefetch' href='//secure.gravatar.com' />
# <link rel='dns-prefetch' href='//ajax.googleapis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <!-- This site uses the Google Analytics by MonsterInsights plugin v7.10.4 - Using Analytics tracking - https://www.monsterinsights.com/ -->
# <script type="text/javascript" data-cfasync="false">
# 	var mi_version         = '7.10.4';
# 	var mi_track_user      = true;
# 	var mi_no_track_reason = '';
#
# 	var disableStr = 'ga-disable-UA-8877314-16';
#
# 	/* Function to detect opted out users */
# 	function __gaTrackerIsOptedOut() {
# 		return document.cookie.indexOf(disableStr + '=true') > -1;
# 	}
#
# 	/* Disable tracking if the opt-out cookie exists. */
# 	if ( __gaTrackerIsOptedOut() ) {
# 		window[disableStr] = true;
# 	}
#
# 	/* Opt-out function */
# 	function __gaTrackerOptout() {
# 	  document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 	  window[disableStr] = true;
# 	}
#
# 	if ( mi_track_user ) {
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','__gaTracker');
#
# 		__gaTracker('create', 'UA-8877314-16', 'auto');
# 		__gaTracker('set', 'forceSSL', true);
# 		__gaTracker('require', 'displayfeatures');
# 		__gaTracker('send','pageview');
# 	} else {
# 		console.log( "" );
# 		(function() {
# 			/* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */
# 			var noopfn = function() {
# 				return null;
# 			};
# 			var noopnullfn = function() {
# 				return null;
# 			};
# 			var Tracker = function() {
# 				return null;
# 			};
# 			var p = Tracker.prototype;
# 			p.get = noopfn;
# 			p.set = noopfn;
# 			p.send = noopfn;
# 			var __gaTracker = function() {
# 				var len = arguments.length;
# 				if ( len === 0 ) {
# 					return;
# 				}
# 				var f = arguments[len-1];
# 				if ( typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function' ) {
# 					console.log( 'Not running function __gaTracker(' + arguments[0] + " ....) because you are not being tracked. " + mi_no_track_reason );
# 					return;
# 				}
# 				try {
# 					f.hitCallback();
# 				} catch (ex) {
#
# 				}
# 			};
# 			__gaTracker.create = function() {
# 				return new Tracker();
# 			};
# 			__gaTracker.getByName = noopnullfn;
# 			__gaTracker.getAll = function() {
# 				return [];
# 			};
# 			__gaTracker.remove = noopfn;
# 			window['__gaTracker'] = __gaTracker;
# 					})();
# 		}
# </script>
# <!-- / Google Analytics by MonsterInsights -->
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/worldagnetwork.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.4.1"}};
# 			/*! This file is auto-generated */
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# 	<link rel='stylesheet' id='wp-block-library-css'  href='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-includes/css/dist/block-library/style.min.css?ver=5.4.1' type='text/css' media='all' />
# <style id='wp-block-library-inline-css' type='text/css'>
# .has-text-align-justify{text-align:justify;}
# </style>
# <link rel='stylesheet' id='adsns_css-css'  href='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/plugins/adsense-plugin/css/adsns.css?ver=1.47' type='text/css' media='all' />
# <link rel='stylesheet' id='rotatingtweets-css'  href='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/plugins/rotatingtweets/css/style.css?ver=5.4.1' type='text/css' media='all' />
# <link rel='stylesheet' id='jetpack_css-css'  href='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/plugins/jetpack/css/jetpack.css?ver=8.3' type='text/css' media='all' />
# <script>if (document.location.protocol != "https:") {document.location = document.URL.replace(/^http:/i, "https:");}</script><script type='text/javascript'>
# /* <![CDATA[ */
# var monsterinsights_frontend = {"js_events_tracking":"true","download_extensions":"doc,pdf,ppt,zip,xls,docx,pptx,xlsx","inbound_paths":"[]","home_url":"https:\/\/worldagnetwork.com","hash_tracking":"false"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/plugins/google-analytics-for-wordpress/assets/js/frontend.min.js?ver=7.10.4'></script>
# <script type='text/javascript' src='https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js?ver=5.4.1'></script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/js/conditionizr.min.js?ver=1.0.0'></script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/js/jquery.cookie.js'></script>
# <link rel='https://api.w.org/' href='https://worldagnetwork.com/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://worldagnetwork.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://worldagnetwork.com/wp-includes/wlwmanifest.xml" />
# <link rel='shortlink' href='https://wp.me/P47UUW-5' />
# <link rel="alternate" type="application/json+oembed" href="https://worldagnetwork.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fworldagnetwork.com%2F" />
# <link rel="alternate" type="text/xml+oembed" href="https://worldagnetwork.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fworldagnetwork.com%2F&#038;format=xml" />
#
# <link rel='dns-prefetch' href='//v0.wordpress.com'/>
# <link rel='dns-prefetch' href='//jetpack.wordpress.com'/>
# <link rel='dns-prefetch' href='//s0.wp.com'/>
# <link rel='dns-prefetch' href='//s1.wp.com'/>
# <link rel='dns-prefetch' href='//s2.wp.com'/>
# <link rel='dns-prefetch' href='//public-api.wordpress.com'/>
# <link rel='dns-prefetch' href='//0.gravatar.com'/>
# <link rel='dns-prefetch' href='//1.gravatar.com'/>
# <link rel='dns-prefetch' href='//2.gravatar.com'/>
# <style type="text/css" media="screen">
# 			  html { margin-top: 0px !important; }
# 			  * html body { margin-top: 0px !important; }
# 			  </style>
# <script src="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/js/jquery.flexslider-min.js"></script>
#
# 	<script>
# 		$.cookie("popup_viewed", "1", {expires: 10, path: "/"});
# 	</script>
#
#
# <link rel="shortcut icon" href="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/images/favicon.ico" />
#
#
#
# <script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
#
#
# <script type='text/javascript'>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/7498709/WAN_Header_Leaderboard', [728, 90], 'div-gpt-ad-1457545662485-0').addService(googletag.pubads());
#     googletag.defineSlot('/7498709/WAN_Footer_Leaderboard', [728, 90], 'div-gpt-ad-1457545662485-1').addService(googletag.pubads());
#     googletag.defineSlot('/7498709/WAN_Home_Skyscraper', [160, 600], 'div-gpt-ad-1457545662485-2').addService(googletag.pubads());
#     googletag.defineSlot('/7498709/WAN_Sidebar_Square', [300, 250], 'div-gpt-ad-1457545662485-3').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
#
#
# <!-- Google reCaptcha -->
# <script src='https://www.google.com/recaptcha/api.js'></script>
#
# <script>
# 	// initialise conditionizr
# 	$('head').conditionizr();
# </script>
#
# </head>
# <body data-rsssl=1 class="home page-template-default page page-id-5" data-responsejs='{
#     "create": [
#     { "breakpoints": [0,768,980], "mode": "markup", "prefix": "r" }
#     ]}'>
#
# <div id="wrapper">
#
# 	<header id="site-header" class="container-fluid">
#
# 		<div id="top-bar" class="row-fluid">
#
# 			<div id="leaderboard" class="ad-position span9">
# 				<!-- /7498709/WAN_Header_Leaderboard -->
# <div id='div-gpt-ad-1457545662485-0' style='height:90px; width:728px;'>
# <script type='text/javascript'>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1457545662485-0'); });
# </script>
# </div>
# 			</div>
#
# 			<div data-r980='<div id="top-subscribe" class="span3">
# 				<p><span>Subscribe to receive the <span style="color: black; display: inline;"><em><strong>WorldAgNetwork</strong></em></span> newsletter!</span></p>
# 				<a href="https://worldagnetwork.com/getusag/" class="btn btn-default btn-block btn-success btn-subscribe">Subscribe Today</a>
# 			</div>'></div>
# 		</div> <!-- #top-bar -->
#
# 		<div id="banner">
# 			<div class="masthead-background bkg-2">
# 			<hgroup>
# 				<h1><a href="https://worldagnetwork.com/">World Agriculture Network</a></h1>
# 				<h2>The World of Agriculture At Your Fingertips</h2>
# 			</hgroup>
# 			</div>
# 		</div> <!-- #banner -->
#
# 		<a href="#site-body" class="skip-to-content">Skip to content</a>
#
# 		<div class="navbar">
# 	      <div class="navbar-inner">
# 			<nav id="main-nav" role="navigation">
# 				<div class="container-fluid">
# 					<a data-target=".nav-collapse" data-toggle="collapse" class="btn btn-info btn-navbar">Menu</a>
#
# 					<div class="nav-collapse collapse"><ul id="menu-menu-1" class="nav"><li id="menu-item-23" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home current-menu-item page_item page-item-5 current_page_item menu-item-23"><a href="https://worldagnetwork.com/" aria-current="page">Home</a></li>
# <li id="menu-item-28" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-28"><a href="https://worldagnetwork.com/category/community/">Community</a></li>
# <li id="menu-item-25" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-25"><a href="https://worldagnetwork.com/category/crops/">Crops</a></li>
# <li id="menu-item-27" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-27"><a href="https://worldagnetwork.com/category/livestock/">Livestock</a></li>
# <li id="menu-item-24" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24"><a href="https://worldagnetwork.com/category/technology/">Technology</a></li>
# <li id="menu-item-26" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-26"><a href="https://worldagnetwork.com/category/business/">Business</a></li>
# <li id="menu-item-29" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-29"><a href="https://worldagnetwork.com/category/policy/">Policy</a></li>
# <li id="menu-item-53" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-53"><a href="https://worldagnetwork.com/category/environment/">Environment</a></li>
# <li id="menu-item-82" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-82"><a href="https://worldagnetwork.com/category/rd/">R&#038;D</a></li>
# </ul></div><!-- .nav-collapse -->
#
# 				<div class="nav-right pull-right">
# 					<form class="navbar-search" role="search" method="get" id="searchform" action="https://worldagnetwork.com/" >
#          <input type="search" name="s" id="s" class="search-query" placeholder="Search this site..." />
#          <button class="search-icon" type="submit" id="searchsubmit">Search</button>
#          </form>
# 					<ul id="connect">
# 						<li class="twitter">
# 							<a class="" title="Twitter" target="_blank" href="https://twitter.com/#!/worldagnetwork">Twitter</a>
# 						</li>
# 						<li class="facebook">
# 							<a class="" title="Facebook" target="_blank" href="https://www.facebook.com/worldagnetwork">Facebook</a>
# 						</li>
# 						<li class="google-plus">
# 							<a class="" title="Google+" target="_blank" href="https://plus.google.com/b/105082105441540512298/105082105441540512298/posts">Google+</a>
# 						</li>
# 						<li class="linked-in">
# 							<a class="" title="LinkedIn" target="_blank" href="http://www.linkedin.com/groups?gid=6525579&goback=.gmp_6525579.gmr_6525579&trk=NUS_UNIU-ngroup">LinkedIn</a>
# 						</li>
# 					</ul>
# 				</div>
#
# 				</div> <!-- .container-fluid -->
# 			</nav><!-- #main-nav -->
#
# 		  </div>
#
#
#
# 		</div><!-- .navbar -->
#
# 			<div id="mobile-subscribe" class="span3 hidden-tablet hidden-desktop">
# 				<p><span>Get the <span style="color: black; display: inline;"><em><strong>WorldAgNetwork</strong></em></span> newsletter!</span></p>
# 				<a href="https://worldagnetwork.com/subscribe/" class="btn btn-large btn-block btn-success btn-subscribe">Subscribe Today</a>
# 			</div>
#
# 	</header> <!-- #site-header -->
#
# 	<div id="site-body" class="container-fluid">
#
# 	<div class="row-fluid">
#
# 		<div class="span8">
#
# 			<div class="row-fluid">
#
#
# <div class="flexslider loading hero-unit group">
#
# 	<div class="slides">
#
#
#
#
# 		<article class="featured-article group">
#
# 			<div class="span6">
# 							</div>
# 			<div class="span6">
# 				<h2><a rel="bookmark" href="https://worldagnetwork.com/u-s-wins-dispute-finding-chinas-grain-tariff-rate-quotas-breaches-wto-commitments%ef%bb%bf/">U.S. Wins Dispute Finding China’s Grain Tariff-Rate Quotas Breaches WTO Commitments﻿</a></h2>
# 				<div class="meta">
# 					<div class="post-author">by USDA Office of Communications</div>
# 											<div class="post-cat"><a href="/category/business/">Business</a> / <a href="/category/policy/">Policy</a> / <a href="/category/press-releases/">Press Releases</a></div>
# 									</div>
# 				<p class="excerpt">U.S. Trade Representative Robert Lighthizer and Secretary of Agriculture Sonny Perdue announced today that a World Trade Organization (WTO) dispute settlement panel found that China has administered its tariff-rate quotas (TRQs) for wheat, corn, and rice inconsistently with its WTO commitments.&nbsp; Contrary to those commitments, China’s TRQ administration is not transparent, predictable, or fair, and it ultimately inhibits TRQs from filling, denying U.S. farmers access to China’s market for grain. This panel report is the ... <a class="readmore" href="https://worldagnetwork.com/u-s-wins-dispute-finding-chinas-grain-tariff-rate-quotas-breaches-wto-commitments%ef%bb%bf/">read more</a></p>			</div>
#
# 		</article>
#
#
#
#
# 		<article class="featured-article group">
#
# 			<div class="span6">
# 				<img width="250" height="250" src="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-250x250.png" class="img-polaroid wp-post-image" alt="" srcset="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-250x250.png 250w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-120x120.png 120w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-150x150.png 150w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-75x75.png 75w" sizes="(max-width: 250px) 100vw, 250px" />			</div>
# 			<div class="span6">
# 				<h2><a rel="bookmark" href="https://worldagnetwork.com/the-2019-edition-of-u-s-agriculture-outlook-is-here/">The 2019 edition of U.S. Agriculture Outlook is here!</a></h2>
# 				<div class="meta">
# 					<div class="post-author">by WorldAgNetwork.com</div>
# 											<div class="post-cat"><a href="/category/business/">Business</a> / <a href="/category/community/">Community</a> / <a href="/category/crops/">Crops</a> / <a href="/category/education/">Education</a> / <a href="/category/environment/">Environment</a> / <a href="/category/livestock/">Livestock</a> / <a href="/category/policy/">Policy</a> / <a href="/category/rd/">R&amp;D</a> / <a href="/category/technology/">Technology</a></div>
# 									</div>
# 				<p class="excerpt"></p>			</div>
#
# 		</article>
#
#
#
#
# 		<article class="featured-article group">
#
# 			<div class="span6">
# 				<img width="250" height="250" src="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-250x250.jpg" class="img-polaroid wp-post-image" alt="PERC engine web 500" srcset="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-250x250.jpg 250w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-280x280.jpg 280w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-400x400.jpg 400w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-120x120.jpg 120w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-150x150.jpg 150w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-75x75.jpg 75w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500.jpg 500w" sizes="(max-width: 250px) 100vw, 250px" />			</div>
# 			<div class="span6">
# 				<h2><a rel="bookmark" href="https://worldagnetwork.com/2019-predictions-for-propane-in-agriculture-qa-with-perc-director-of-ag-business-development-mike-newland-sponsored/">2019 Predictions for Propane in Agriculture: Q&#038;A with PERC Director of Ag Business Development Mike Newland (Sponsored)</a></h2>
# 				<div class="meta">
# 					<div class="post-author">by Propane Education and Research Council</div>
# 											<div class="post-cat"><a href="/category/interview/">Interview</a></div>
# 									</div>
# 				<p class="excerpt">What does the future of propane in agriculture look like, and what is new with propane-powered farm equipment in 2019? The Propane Education &amp; Research Council’s new Director of Agriculture Business Development, Mike Newland, discusses this and much more in the following question and answer session. Read on for more information about new propane-powered equipment, the future of propane, and the many benefits clean, American-made propane offers farmers. Q: What can the agricultural community expect ... <a class="readmore" href="https://worldagnetwork.com/2019-predictions-for-propane-in-agriculture-qa-with-perc-director-of-ag-business-development-mike-newland-sponsored/">read more</a></p>			</div>
#
# 		</article>
#
#
#
#
# 		<article class="featured-article group">
#
# 			<div class="span6">
# 				<img width="250" height="250" src="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-250x250.jpg" class="img-polaroid wp-post-image" alt="picking a vet cattle inspection web" srcset="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-250x250.jpg 250w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-280x280.jpg 280w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-400x400.jpg 400w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-120x120.jpg 120w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-150x150.jpg 150w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-75x75.jpg 75w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web.jpg 500w" sizes="(max-width: 250px) 100vw, 250px" />			</div>
# 			<div class="span6">
# 				<h2><a rel="bookmark" href="https://worldagnetwork.com/picking-a-vet/">Picking a Vet</a></h2>
# 				<div class="meta">
# 					<div class="post-author">by Eric Seeger</div>
# 											<div class="post-cat"><a href="/category/livestock/">Livestock</a></div>
# 									</div>
# 				<p class="excerpt">Eric Klein has been around animals all his life. He grew up on his family’s hobby farm in New Jersey, and he would sometimes do work for other farmers nearby. After college, he worked on a cattle ranch out West, and today he and his wife operate Hidden Stream Farm in Elgin, Minnesota, where they practice sustainable farming and finish grass-fed beef, deep-bedded hogs, and pasture chickens. He’s proud to say that his methods of ... <a class="readmore" href="https://worldagnetwork.com/picking-a-vet/">read more</a></p>			</div>
#
# 		</article>
#
#
#
#
# 		<article class="featured-article group">
#
# 			<div class="span6">
# 				<img width="250" height="250" src="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/tree-nuts-almond-web-250x250.jpg" class="img-polaroid wp-post-image" alt="tree nuts almond web" srcset="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/tree-nuts-almond-web-250x250.jpg 250w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/tree-nuts-almond-web-280x280.jpg 280w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/tree-nuts-almond-web-400x400.jpg 400w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/tree-nuts-almond-web-120x120.jpg 120w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/tree-nuts-almond-web-150x150.jpg 150w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/tree-nuts-almond-web-75x75.jpg 75w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/tree-nuts-almond-web.jpg 500w" sizes="(max-width: 250px) 100vw, 250px" />			</div>
# 			<div class="span6">
# 				<h2><a rel="bookmark" href="https://worldagnetwork.com/a-good-time-to-go-nuts/">A Good Time to Go Nuts</a></h2>
# 				<div class="meta">
# 					<div class="post-author">by Craig Collins</div>
# 											<div class="post-cat"><a href="/category/crops/">Crops</a></div>
# 									</div>
# 				<p class="excerpt">As developing countries continue to grow their middle classes, markets for many specialty crops – including tree nuts – continue to grow along with them. The International Nut and Dried Fruit Council (INC) estimates that growers around the world will produce about 4.2 million metric tons of tree nuts during the 2017-2018 season, 11 percent more than the previous year and about 30 percent more than the past decade’s average annual production. The United States ... <a class="readmore" href="https://worldagnetwork.com/a-good-time-to-go-nuts/">read more</a></p>			</div>
#
# 		</article>
#
#
# 	</div><!-- .slides -->
#
# </div><!-- .flexslider -->
#
#
#
#
#
#
# <script type="text/javascript">
#
# (function($) { // no-conflict mode
#
#     var flexslider = $('.flexslider');
#     $(window).load(function(){
#       flexslider.flexslider({
#       	slideshowSpeed: 4000,
#       	smoothHeight: true,
#       	pauseOnHover: true,
#         selector: ".slides > .featured-article",
#         start: function() {
#         	slideHeight();
#         	flexslider.removeClass('loading');
#         	swipeMessage();
#         }
#       });
#     });
#
#     function swipeMessage() {
#
#     	if (Modernizr.touch) {
# 		    flexslider.append('<span class="swipe-message">Swipe for next story <i class="icon-exchange"></i></span>');
# 		    flexslider.find('.swipe-message').delay(1500).fadeOut();
# 		}
# 	}
#
# 	function slideHeight() {
#
# 		var slides = flexslider.find('article.featured-article'),
# 			maxHeight = -1;
#
# 		slides.each(function(index) {
# 			var slideHt = $(this).outerHeight(true);
# 			if(slideHt > maxHeight)
# 				maxHeight = slideHt;
# 			// console.log(slideHt);
# 		});
# 		// console.log(maxHeight);
# 		slides.css('minHeight', maxHeight + 'px');
# 	}
#
# })(jQuery);
#
#
# </script>
# 			</div><!-- .row-fluid -->
#
# 			<div class="row-fluid">
#
# 				<div id="three-col-left" class="group span8">
#
# 	<div class="tablet-lhs">
#
#
#
# 	<div id="recent-articles" class="posts-index">
#
#
#
# 				<article class="m-both post group">
#
# 				<div class="post-thumbnail">
# 									</div>
# 				<h3><a rel="bookmark" href="https://worldagnetwork.com/u-s-wins-dispute-finding-chinas-grain-tariff-rate-quotas-breaches-wto-commitments%ef%bb%bf/">U.S. Wins Dispute Finding China’s Grain Tariff-Rate Quotas Breaches WTO Commitments﻿</a></h3>
# 				<div class="post-author">by USDA Office of Communications</div>
# 									<div class="post-cat"><a href="/category/business/">Business</a> / <a href="/category/policy/">Policy</a> / <a href="/category/press-releases/">Press Releases</a></div>
#
# 				<p class="excerpt">U.S. Trade Representative Robert Lighthizer and Secretary of Agriculture Sonny Perdue announced today that a World Trade Organization (WTO) dispute settlement panel found that China has administered its tariff-rate quotas ... <a class="readmore" href="https://worldagnetwork.com/u-s-wins-dispute-finding-chinas-grain-tariff-rate-quotas-breaches-wto-commitments%ef%bb%bf/">read more</a></p>
# 			</article><!-- .post -->
#
#
# 				<article class="m-both post group">
#
# 				<div class="post-thumbnail">
# 					<img width="120" height="120" src="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-120x120.png" class="img-polaroid wp-post-image" alt="" srcset="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-120x120.png 120w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-250x250.png 250w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-150x150.png 150w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Screen-Shot-2019-04-17-at-4.52.14-PM-75x75.png 75w" sizes="(max-width: 120px) 100vw, 120px" />				</div>
# 				<h3><a rel="bookmark" href="https://worldagnetwork.com/the-2019-edition-of-u-s-agriculture-outlook-is-here/">The 2019 edition of U.S. Agriculture Outlook is here!</a></h3>
# 				<div class="post-author">by WorldAgNetwork.com</div>
# 									<div class="post-cat"><a href="/category/business/">Business</a> / <a href="/category/community/">Community</a> / <a href="/category/crops/">Crops</a> / <a href="/category/education/">Education</a> / <a href="/category/environment/">Environment</a> / <a href="/category/livestock/">Livestock</a> / <a href="/category/policy/">Policy</a> / <a href="/category/rd/">R&amp;D</a> / <a href="/category/technology/">Technology</a></div>
#
# 				<p class="excerpt"></p>
# 			</article><!-- .post -->
#
#
# 				<article class="m-both post group">
#
# 				<div class="post-thumbnail">
# 					<img width="120" height="120" src="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-120x120.jpg" class="img-polaroid wp-post-image" alt="PERC engine web 500" srcset="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-120x120.jpg 120w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-280x280.jpg 280w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-400x400.jpg 400w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-250x250.jpg 250w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-150x150.jpg 150w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500-75x75.jpg 75w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2019/03/PERC-engine-web-500.jpg 500w" sizes="(max-width: 120px) 100vw, 120px" />				</div>
# 				<h3><a rel="bookmark" href="https://worldagnetwork.com/2019-predictions-for-propane-in-agriculture-qa-with-perc-director-of-ag-business-development-mike-newland-sponsored/">2019 Predictions for Propane in Agriculture: Q&#038;A with PERC Director of Ag Business Development Mike Newland (Sponsored)</a></h3>
# 				<div class="post-author">by Propane Education and Research Council</div>
# 									<div class="post-cat"><a href="/category/interview/">Interview</a></div>
#
# 				<p class="excerpt">What does the future of propane in agriculture look like, and what is new with propane-powered farm equipment in 2019? The Propane Education &amp; Research Council’s new Director of Agriculture ... <a class="readmore" href="https://worldagnetwork.com/2019-predictions-for-propane-in-agriculture-qa-with-perc-director-of-ag-business-development-mike-newland-sponsored/">read more</a></p>
# 			</article><!-- .post -->
#
#
# 				<article class="m-both post group">
#
# 				<div class="post-thumbnail">
# 					<img width="120" height="120" src="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/07/Gerard-Bogdon-120x120.jpg" class="img-polaroid wp-post-image" alt="" srcset="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/07/Gerard-Bogdon-120x120.jpg 120w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/07/Gerard-Bogdon-280x280.jpg 280w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/07/Gerard-Bogdon-768x768.jpg 768w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/07/Gerard-Bogdon-400x400.jpg 400w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/07/Gerard-Bogdon-250x250.jpg 250w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/07/Gerard-Bogdon-150x150.jpg 150w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/07/Gerard-Bogdon-75x75.jpg 75w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/07/Gerard-Bogdon.jpg 960w" sizes="(max-width: 120px) 100vw, 120px" />				</div>
# 				<h3><a rel="bookmark" href="https://worldagnetwork.com/phytelligence-announces-new-global-vice-president-of-sales-for-citrus/">Phytelligence Announces New Global Vice President of Sales for Citrus</a></h3>
# 				<div class="post-author">by Damion</div>
# 									<div class="post-cat"><a href="/category/business/">Business</a> / <a href="/category/crops/">Crops</a> / <a href="/category/press-releases/">Press Releases</a></div>
#
# 				<p class="excerpt">Horticulture professional, Gerard Bogdon joins Seattle-based startup to lead company’s citrus sales. July 10, 2018 – Phytelligence, a leading agricultural biotechnology company that is revolutionizing the way food crops are grown, today ... <a class="readmore" href="https://worldagnetwork.com/phytelligence-announces-new-global-vice-president-of-sales-for-citrus/">read more</a></p>
# 			</article><!-- .post -->
#
#
# 				<article class="m-both post group">
#
# 				<div class="post-thumbnail">
# 					<img width="120" height="120" src="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-120x120.jpg" class="img-polaroid wp-post-image" alt="picking a vet cattle inspection web" srcset="https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-120x120.jpg 120w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-280x280.jpg 280w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-400x400.jpg 400w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-250x250.jpg 250w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-150x150.jpg 150w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web-75x75.jpg 75w, https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/picking-a-vet-cattle-inspection-web.jpg 500w" sizes="(max-width: 120px) 100vw, 120px" />				</div>
# 				<h3><a rel="bookmark" href="https://worldagnetwork.com/picking-a-vet/">Picking a Vet</a></h3>
# 				<div class="post-author">by Eric Seeger</div>
# 									<div class="post-cat"><a href="/category/livestock/">Livestock</a></div>
#
# 				<p class="excerpt">Eric Klein has been around animals all his life. He grew up on his family’s hobby farm in New Jersey, and he would sometimes do work for other farmers nearby. ... <a class="readmore" href="https://worldagnetwork.com/picking-a-vet/">read more</a></p>
# 			</article><!-- .post -->
#
# 	</div><!-- #recent-articles -->
#
#
#
# 	</div><!-- .tablet-lhs -->
#
# </div><!-- .span5 -->
# 				<div id="centre-column" class="span4 group">
#
#
#
# <div id="selected-articles-1" class="widget">
#
# <h3>Opinion</h3>
#
# <ul id="opinion">
#
#
#
# 	<li class="group">
# 		<a href="https://worldagnetwork.com/u-s-wins-dispute-finding-chinas-grain-tariff-rate-quotas-breaches-wto-commitments%ef%bb%bf/">U.S. Wins Dispute Finding China’s Grain Tariff-Rate Quotas Breaches WTO Commitments﻿</a>
# 		<span class="excerpt-span">U.S. Trade Representative Robert Lighthizer and Secretary of Agriculture Sonny Perdue announced today that a<a href="https://worldagnetwork.com/u-s-wins-dispute-finding-chinas-grain-tariff-rate-quotas-breaches-wto-commitments%ef%bb%bf/"> ...<i class="icon-chevron-right"></i></a></span>	</li>
#
#
#
# 	<li class="group">
# 		<a href="https://worldagnetwork.com/the-2019-edition-of-u-s-agriculture-outlook-is-here/">The 2019 edition of U.S. Agriculture Outlook is here!</a>
# 		<span class="excerpt-span"></span>	</li>
#
#
#
# 	<li class="group">
# 		<a href="https://worldagnetwork.com/ncga-releases-statement-on-proposed-tariffs-and-trade-with-china/">NCGA Releases Statement on Proposed Tariffs and Trade with China</a>
# 		<span class="excerpt-span">(WASHINGTON) April 4, 2018 &#8212; “There are no winners in a trade war, only casualties.  As trade<a href="https://worldagnetwork.com/ncga-releases-statement-on-proposed-tariffs-and-trade-with-china/"> ...<i class="icon-chevron-right"></i></a></span>	</li>
#
#
#
# 	<li class="group">
# 		<a href="https://worldagnetwork.com/a-major-contribution/">A Major Contribution</a>
# 		<span class="excerpt-span">Australia relies on surface water storages to ensure that water is available when needed and<a href="https://worldagnetwork.com/a-major-contribution/"> ...<i class="icon-chevron-right"></i></a></span>	</li>
#
#
# </ul>
#
# </div>
#
#
#
# <div id="selected-articles-2" class="widget">
#
# <h3>Editor's Pick</h3>
#
# <ul id="editors-pick">
#
#
#
# 	<li><a href="https://worldagnetwork.com/u-s-wins-dispute-finding-chinas-grain-tariff-rate-quotas-breaches-wto-commitments%ef%bb%bf/">U.S. Wins Dispute Finding China’s Grain Tariff-Rate Quotas Breaches WTO Commitments﻿</a></li>
#
#
#
# 	<li><a href="https://worldagnetwork.com/the-2019-edition-of-u-s-agriculture-outlook-is-here/">The 2019 edition of U.S. Agriculture Outlook is here!</a></li>
#
#
#
# 	<li><a href="https://worldagnetwork.com/latest-edition-of-faircounts-world-agriculture-outlook-debuts-at-world-ag-expo/">Latest Edition of Faircount&#8217;s World Agriculture Outlook Debuts at World Ag Expo</a></li>
#
#
#
# 	<li><a href="https://worldagnetwork.com/teen-creates-famr-safety-app-to-reduce-heat-illness-and-deaths-among-farm-workers/">Teen Creates Farm Safety App to Reduce Heat Illness and Deaths Among Farm Workers</a></li>
#
#
#
# 	<li><a href="https://worldagnetwork.com/us-agriculture-outlook-2017-emagazine-latest-release/">U.S. Agriculture OUTLOOK 2017</a></li>
#
#
# </ul>
#
# </div>
#
#
# 	<div id="skyscraper" class="ad-position hidden-phone">
# 		<!-- /7498709/WAN_Home_Skyscraper -->
# <div id='div-gpt-ad-1457545662485-2' style='height:600px; width:160px;'>
# <script type='text/javascript'>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1457545662485-2'); });
# </script>
# </div>
# 	</div>
#
#
# </div><!-- .span3 -->
# 			</div><!-- .row-fluid -->
#
# 		</div><!-- .span8 -->
#
# 		<aside id="sidebar" class="group span4">
#
# 	<div id="tablet-subscribe" class="widget hidden-phone hidden-desktop">
# 		<p><span>Get the <span style="color: black; display: inline;"><em><strong>WorldAgNetwork</strong></em></span> newsletter!</span></p>
# 				<a href="https://worldagnetwork.com/subscribe/" class="btn btn-large btn-block btn-success btn-subscribe">Subscribe Today</a>
# 	</div>
#
# 	<div id="subscribe" class="widget">
# 		<h3>Subscribe!<br>(eNewsletter, Print and/or Digital Edition)</h3>
# 		<p><center>Sign up to receive a free copy of the upcoming edition of U.S. Agriculture: Outlook and/or our newsletter.</center></p>
# 		<p><center><a href="https://worldagnetwork.com/getusag/" class="btn btn-warning btn-default">Add Me!</center></a></p>
# 	</div>
#
# 	<div id="email-editor" class="widget">
# 		<h3>News Submissions</h3>
# 		<p>Is your organization or product making a positive impact on the world of agriculture?</p>
# 		<br>
# 		<p>If so, WorldAgNetwork would like to share your organization's story via an article, video, or photo gallery.</p>
# 		<br>
# 		<p><a href="https://worldagnetwork.com/submit-your-news/" class="btn btn-warning btn-default">
# 			<i class="icon-envelope"></i> Submit News</a></p>
# 		<br>
# 		<small><i>Submissions will be accepted at the discretion of the publisher.</i></small>
# 	</div>
#
# 	<div id="square-ad" class="ad-position">
# 		<!-- /7498709/WAN_Sidebar_Square -->
# <div id='div-gpt-ad-1457545662485-3' style='height:250px; width:300px;'>
# <script type='text/javascript'>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1457545662485-3'); });
# </script>
# </div>
# 	</div>
#
# 	<div id="digital-edition" class="widget">
# 		<h3>U.S. Agriculture Outlook</h3><div class="textwidget"><iframe style="width: 100%; height: 400px;" src="//e.issuu.com/embed.html#23813436/59478820" width="300" height="150" frameborder="0" allowfullscreen="allowfullscreen"></iframe></div>	</div><!-- #digital-edition -->
#
# </aside>
# 	</div><!-- .row-fluid -->
#
# 	</div> <!-- #site-body -->
#
# 	<footer id="site-footer" class="container-fluid">
#
# 		<div class="row-fluid">
#
# 			<div class="well group">
#
# 			<section class="span4">
# 				<h4>About Faircount Media Group</h4>
# 				<p><em>Faircount Media Group</em> is an independent custom publisher producing niche B2B magazines for a varied portfolio of media clients ranging from government to sport and luxury brands. Faircount Media Group also publishes a range of highly acclaimed in-house titles across defense, infrastructure, and health. Faircount Media Group has offices in the United States, the United Kingdom, and Australia.</p>
# 				<p>To find out more, please visit <a href="http://faircount.com/" target="_blank">faircount.com<i class="icon-external-link"></i></a></p>
# 			</section>
#
# 			<section class="span4">
# 				<h4>About the World Agriculture Network</h4>
# 				<p><em>WorldAgNetwork.com</em> is a website dedicated to the advancement of global agriculture objectives, delivering in-depth coverage of agriculture initiatives around the world.</p>
# 				<p>WorldAgNetwork.com provides insight into the people, programs, and technologies that will feed the world for decades to come. Born out of the success of Faircount Media Group's publication U.S. Agriculture Outlook, WorldAgNetwork.com is designed to stimulate discussion and facilitate the exchange of public opinion amongst industry members to identify the current state and future challenges of agriculture and agribusiness around the globe.</p>
# 			</section>
#
# 			<section class="span4">
# 				<h4>Contact Us</h4>
# 				<p>If you would like to make a suggestion, report a problem with this site, update your subscription preferences or otherwise contact us, please complete our <a href="https://worldagnetwork.com/contact-editor/">Contact Form</a>.</p>
# 				<p>To find out more about advertising on the World Agriculture Network, please <a href="https://worldagnetwork.com/advertise/">contact our advertising department<i class="icon-envelope"></i></a>.</p>
# 			</section>
#
# 		</div> <!-- .well -->
#
# 		</div>
#
# 		<div class="row-fluid">
#
# 			<div id='footer-ad' class='ad-position hidden-phone'>
# 				<!-- /7498709/WAN_Footer_Leaderboard -->
# <div id='div-gpt-ad-1457545662485-1' style='height:90px; width:728px;'>
# <script type='text/javascript'>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1457545662485-1'); });
# </script>
# </div>			</div>
#
# 		</div>
#
# 	</footer>
#
#
# </div><!-- #wrapper -->
#
#
# 	<div id="sub-footer" class="row-fluid">
#
# 		<p>&copy; Faircount Media Group 2013</p>
#
# 	</div>
#
# 	<div style="display:none">
# 	</div>
# <script type='text/javascript' src='https://secure.gravatar.com/js/gprofiles.js?ver=2020Mayaa'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var WPGroHo = {"my_hash":""};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/plugins/jetpack/modules/wpgroho.js?ver=5.4.1'></script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/js/modernizr.js?ver=2.6.2'></script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/js/bootstrap.min.js?ver=2.2.2-plus-responsive'></script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/js/jquery.lazy.min.js?ver=0.1.1'></script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/js/response.min.js?ver=0.7.5'></script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-content/themes/rtntheme/js/project.js?ver=1'></script>
# <script type='text/javascript' src='https://mm6uc179li73niyiw4d0xxcqs8-wpengine.netdna-ssl.com/wp-includes/js/wp-embed.min.js?ver=5.4.1'></script>
# <script type='text/javascript' src='https://stats.wp.com/e-202020.js' async='async' defer='defer'></script>
# <script type='text/javascript'>
# 	_stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:8.3',blog:'60992434',post:'5',tz:'-4',srv:'worldagnetwork.com'} ]);
# 	_stq.push([ 'clickTrackerInit', '60992434', '5' ]);
# </script>
#
#
# </body>
# </html>
