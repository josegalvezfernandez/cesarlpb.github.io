# %% [markdown]
# ## Repaso clase anterior 11-05
# Conexión a URL con Python

# %%
url = 'https://www.idealista.com/alquiler-habitacion/madrid/centro/mapa'
type(url)
url.capitalize
url.capitalize()

# %%
import requests
response = requests.get(url)
print(response)
type(response)
print(response)
response

# %%
url = 'https://www.google.es'
response = requests.get(url)
response
#etc.

# %%
print(response.text)

# %%
#python
#Script básico para conectar a una web con python
import requests
# Declaro la variable url que aparece varias veces 
url = 'https://www.idealista.com/alquiler-habitacion/madrid/centro/mapa'
response = requests.get(url)
response
# error 403 = Forbidden / Prohibido
url = 'http://web.mta.info/developers/turnstyle.html'
response = requests.get(url)
response
# response 200 = Success / Conexión con éxito
#Google
url = 'https://www.google.es'
response = requests.get(url)
response
#etc.

#Cuando hay conexión:
print(response.text) #sale todo el HTML que hayas encontrado en la URL

# %% [markdown]
# ## Clase 2 13-05
# Conexión con Oauth a API y scrap de páginas, conseguir tag <a>

# %%
# FUNCIONA
import requests, json
import urllib3
#urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# "https://api.idealista.com/oauth/token"
#  'zv3u0zzhv10ojbnnrzm1rhc4rnxpjcv5'
# 'L4z1zpuu1LKH'

token_url = "https://api.idealista.com/oauth/token"

test_api_url = "https://api.idealista.com/oauth"

#client (application) credentials on apim.byu.edu
client_id = 'zv3u0zzhv10ojbnnrzm1rhc4rnxpjcv5'
client_secret = 'L4z1zpuu1LKH'

#step A, B - single call with client credentials as the basic auth header - will return access_token
data = {'grant_type': 'client_credentials'}

access_token_response = requests.post(token_url, data=data, verify=False, allow_redirects=False, auth=(client_id, client_secret))
print("HEADERS:")
print(access_token_response.headers)
print("TEXT:")
print(access_token_response.text)

tokens = json.loads(access_token_response.text)

#print("access token: " + tokens['access_token'])

#step B - with the returned access_token we can make as many calls as we want

api_call_headers = {'Authorization': 'Bearer ' + tokens['access_token']}
api_call_response = requests.get(test_api_url, headers=api_call_headers, verify=False)
# Out:
# HEADERS:
# {'Server': 'idealista', 'Date': 'Mon, 18 May 2020 15:33:15 GMT', 'Content-Type': 'application/json;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Cache-Control': 'no-store', 'Set-Cookie': 'APIPUBID=6ea731eb53d275e7|XsKqY|XsKqY; path=/; HttpOnly; Secure'}
# TEXT:
# {"access_token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU4OTg1OTE5NSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiZTUwYTU4YWYtZDBlOS00ODgzLWIwNmMtNzExMjg2YThmNDhhIiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.wA9un9XM4zynx5rIHczEQYsDzUE-lj3CL_ORlSK1tJI","token_type":"bearer","expires_in":43199,"scope":"read","jti":"e50a58af-d0e9-4883-b06c-711286a8f48a"}

# %%
resp = api_call_response
print('TYPE: ' + str(type(resp)))
print('JSON: ' + str(resp.json()))
print('PRINT: ' + str(resp))
# Out:
# TYPE: <class 'requests.models.Response'>
# JSON: {'message': 'not found', 'httpStatus': 404}
# PRINT: <Response [404]>

# %%
# OBSOLETO // FUENTE: https://stackoverflow.com/questions/40023931/how-to-get-real-estate-data-with-idealista-api
# Función para conectar con API

import httplib2
import base64
def get_oauth_token():
    http_obj = Http()
    url = "https://api.idealista.com/oauth/token"
    apikey= urllib.parse.quote_plus('zv3u0zzhv10ojbnnrzm1rhc4rnxpjcv5')
    secret= urllib.parse.quote_plus('L4z1zpuu1LKH')
    auth = base64.encode(apikey + ':' + secret)
    body = {'grant_type':'client_credentials'}
    headers = {'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8','Authorization' : 'Basic ' + auth}
    resp, content = request(url,method='POST',headers=headers, body=urllib.parse.urlencode(body))
    return content
get_oauth_token()

# %%
# OBSOLETO
# Añadido guardado en texto
def get_oauth_token():
	http_obj = Http()
	url = "https://api.idealista.com/oauth/token"
	apikey= urllib.parse.quote_plus('zv3u0zzhv10ojbnnrzm1rhc4rnxpjcv5')
	secret= urllib.parse.quote_plus('L4z1zpuu1LKH')
	auth = base64.encode(apikey + ':' + secret)
	body = {'grant_type':'client_credentials'}
	headers = {'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8','Authorization' : 'Basic ' + auth}
	resp, content = http_obj.request(url,method='POST',headers=headers, body=urllib.parse.urlencode(body))
	#Escribir en TXT
	text_file = open("session_token.txt", "w")
	text_file.write(content.text)
	text_file.close()
	return content
get_oauth_token()

# %% [markdown]
# ## Requests

# %%
import requests
# r = requests.get('https://api.github.com/user', auth=('user', 'pass'))
r = requests.get('https://www.google.es') #https://api.github.com/user
r.status_code

# %%
r.headers['content-type']

# %%
r.encoding

# %%
r.text

# %%
r.json() #solo funciona si bajamos un JSON

# %%
import requests
url = 'http://worldagnetwork.com/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
print(result.content.decode())

# %%
#pip install bs4 # antes este módulo se llamaba BeautifulSoup
#pip install urllib	# solo en caso de no tenerlo ya

from bs4 import BeautifulSoup as BS # importamos un paquete del módulo
import urllib	# antes se llamaba urlib2
from urllib.request import urlopen # pedimos la función urlopen a la librería
url = 'https://www.crummy.com/software/BeautifulSoup/bs4/doc/'
#url = 'http://web.mta.info/developers/turnstile.html' # url en variable como string
html = urlopen(url)
html

# %%
html
print(html)
type(html)
#html.text

# %%
# print(html)
soup = BS(html)	#aplicamos beautifulsoup al hrml que hemos obtenido
print(soup.prettify())
soup.title

# %%
elem = soup.find_all('<a')	#hallamos todos los a tags
# <a href="link" attrs>Texto visible</a>
# Texto visible

for i in range(1):	#bucle para ver los primeros 5 elementos
    print(elem[i])

# %%
from bs4 import BeautifulSoup as BS # importamos un paquete del módulo
import urllib	# antes se llamaba urlib2
from urllib.request import urlopen # pedimos la función urlopen a la librería


url = 'https://www.google.es' # url en variable como string
html = urlopen(url)
# print(html)
soup = BS(html)	#aplicamos beautifulsoup al hrml que hemos obtenido
# print(soup)

elem = soup.find_all('a')	#hallamos todos los a tags
# <a href="link" attrs>Texto visible</a>

for i in range(5):	#bucle para ver los primeros 5 elementos
	print(elem[i])

# %% [markdown]
# ### Ejercicios próxima clase: https://cesarlpb.github.io/Python/#ejs

# %% [markdown]
# ## Clase 18-05

# %% [markdown]
# #### Scrap de URL: https://www.tecnicasa.net/promociones/823614891

# %%
from bs4 import BeautifulSoup as BS
import urllib
from urllib.request import urlopen
#url = 'https://www.tecnicasa.net/promociones/823614891'
url = 'https://www.tecnicasa.net/promociones/641139761'
#url = 'https://www.google.es'
html = urlopen(url) # https://docs.python.org/3/library/urllib.request.html

# %%
soup = BS(html)
elem = soup.find_all('<a')
#for i in range(5):
#	print(elem[i])
soup.text

# %%
import urllib.request

fp = urllib.request.urlopen("https://www.tecnicasa.net/promociones/641139761")
mybytes = fp.read()

mystr = mybytes.decode("utf8")
fp.close()

print(mystr)

# %%
# Hay que agregar webdriver al PATH
###
from selenium import webdriver
url = "https://www.tecnicasa.net/promociones/641139761"
browser = webdriver.Firefox()
browser.get(url)
sleep(10)
all_body_id_html =  browser.find_element_by_id('body')

# %%
# Alternativa a Selenium

import mechanize 

mb = mechanize.Browser()
mb.addheaders = [('User-agent', 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1')] 
mb.set_handle_robots(False)
# url = "http://www.gallimard-jeunesse.fr/searchjeunesse/advanced/(order)/author?catalog[0]=1&SearchAction=1"
url = "https://www.tecnicasa.net/promociones/641139761"
response = mb.open(url).read()
print(response)
# Out:
# b'<!doctype html><html lang="es"><head><meta charset="utf-8"><title>Venta y alquiler de pisos en Badajoz | Tecnicasa.net</title><base href="/"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" type="image/x-icon" href="favicon.ico"><link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"><link href="https://fonts.googleapis.com/css?family=Montserrat:400,500,700" rel="stylesheet"><link href="styles.45190e4f20c980db4ca6.bundle.css" rel="stylesheet"/></head><body><app-root></app-root><script type="text/javascript" src="inline.318b50c57b4eba3d437b.bundle.js"></script><script type="text/javascript" src="polyfills.98b5c43ab35999b30c16.bundle.js"></script><script type="text/javascript" src="scripts.ec17d636791d5daccd0a.bundle.js"></script><script type="text/javascript" src="main.a343131ec89bcbfee957.bundle.js"></script></body></html>'

# %%
import codecs
f=codecs.open("test.html", 'r')
print(f.read())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>Test</title>
# </head>
#
# <body>
# 	<h1>Esto es una prueba de HTML</h1>
# 	Texto
# 	<p>Texto en p.</p>
# </body>
#
# </html>

# %%
# Una vez tenemos el HTML
#url = https://www.idealista.com/alquiler-habitacion/madrid/centro/lavapies-embajadores/
from bs4 import BeautifulSoup as BS
import urllib
from urllib.request import urlopen
#page = open("embajadores.html")

with open(r'embajadores.html', "r", encoding='utf-8') as f:
    page = f.read()
page
# Out:
# '\n<!DOCTYPE html>\n\n\n\n\n\n \n\n\n\n\n\n\n\n<!--[if IE 8]><html class="ie8" lang="es" env="es" username=""><![endif]--> <!--[if IE 9]><html class="ie9" lang="es" env="es" username=""><![endif]--> <!--[if gt IE 9]><!--> <html lang="es" env="es" username="" data-userAuth="false"><!--<![endif]--> <head> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> <title>Habitaciones en alquiler en Lavapiés-Embajadores, Madrid &#8212; idealista</title> <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"> <meta name="description" content="Habitaciones en alquiler en Lavapiés-Embajadores, a partir de 270 euros de particulares e inmobiliarias. Alquiler habitaciones en Lavapiés-Embajadores: anuncios de particular a particular y de agencias inmobiliarias."> <meta name="author" content="idealista.com"> <meta http-equiv="cleartype" content="on"> <meta name="pragma" content="no-cache"/> <meta http-equiv="Pragma" content="no-cache"/> <meta http-equiv="Expires" content="Fri, 01
# ...

# %% [markdown]
# ## Pandas

# %%
# Sirve para manipular datos en Python
# https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html

# %%
# CSV
import pandas as pd
df = pd.read_csv("olympics.csv")
