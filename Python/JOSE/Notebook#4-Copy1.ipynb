# %%
#API Idealista

# %%
#1
import json
import datetime
import requests
from requests.auth import HTTPBasicAuth
import exceptions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-cec5ac7c99dc> in <module>
#       4 import requests
#       5 from requests.auth import HTTPBasicAuth
# ----> 6 import exceptions
#
# ModuleNotFoundError: No module named 'exceptions'

# %%
#2
apikey = 'zv3u0zzhv10ojbnnrzm1rhc4rnxpjcv5' # APYKEY
secret = 'L4z1zpuu1LKH'
auth_url = "https://api.idealista.com/oauth/token"
api_base_url = "http://api.idealista.com/3.5/{country}/search"

# %%
auth = HTTPBasicAuth(apikey, secret)
headers = {'Content-Type': ('application/'
                            'x-www-form-urlencoded;charset=UTF-8')}
payload = {'grant_type': 'client_credentials',
           'scope': 'read'}
response = requests.post(auth_url,
                         headers=headers,
                         data=payload,
                         auth=auth)
response
type(response)
print(response)
# Out:
# <Response [200]>

# %%
json.loads(response.text)
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDg4MDE2NiwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiOWQwNmU4MGEtZDA0My00ZGUwLWFiYmQtZDg0MTkxZDViMjY1IiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.0CcHnG-ahPftyQwR0JVhEeQqPH_DdTQ7ORu4RZh_X_4',
#  'token_type': 'bearer',
#  'expires_in': 43199,
#  'scope': 'read',
#  'jti': '9d06e80a-d043-4de0-abbd-d84191d5b265'}

# %%
type(response)
# Out:
# requests.models.Response

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
help(response)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  close(self)
#  |      Releases the connection back to the pool. Once this method has been
#  |      called the underlying ``raw`` object must not be accessed again.
#  |
#  |      *Note: Should not normally need to be called explicitly.*
#  |
#  |  iter_content(self, chunk_size=1, decode_unicode=False)
#  |      Iterates over the response data.  When stream=True is set on the
#  |      request, this avoids reading the content at once into memory for
#  |      large responses.  The chunk size is the number of bytes it should
#  |      read into memory.  This is not necessarily the length of each item
#  |      returned as decoding can take place.
#  |
#  |      chunk_size must be of type int or None. A value of None will
#  |      function differently depending on the value of `stream`.
#  |      stream=True will read data as it arrives in whatever size the
#  |      chunks are received. If stream=False, data is returned as
#  |      a single chunk.
#  |
#  |      If decode_unicode is True, content will be decoded using the best
#  |      available encoding based on the response.
#  |
#  |  iter_lines(self, chunk_size=512, decode_unicode=False, delimiter=None)
#  |      Iterates over the response data, one line at a time.  When
#  |      stream=True is set on the request, this avoids reading the
#  |      content at once into memory for large responses.
#  |
#  |      .. note:: This method is not reentrant safe.
#  |
#  |  json(self, **kwargs)
#  |      Returns the json-encoded content of a response, if any.
#  |
#  |      :param \*\*kwargs: Optional arguments that ``json.loads`` takes.
#  |      :raises ValueError: If the response body does not contain valid json.
#  |
#  |  raise_for_status(self)
#  |      Raises stored :class:`HTTPError`, if one occurred.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  apparent_encoding
#  |      The apparent encoding, provided by the chardet library.
#  |
#  |  content
#  |      Content of the response, in bytes.
#  |
#  |  is_permanent_redirect
#  |      True if this Response one of the permanent versions of redirect.
#  |
#  |  is_redirect
#  |      True if this Response is a well-formed HTTP redirect that could have
#  |      been processed automatically (by :meth:`Session.resolve_redirects`).
#  |
#  |  links
#  |      Returns the parsed header links of the response, if any.
#  |
#  |  next
#  |      Returns a PreparedRequest for the next request in a redirect chain, if there is one.
#  |
#  |  ok
#  |      Returns True if :attr:`status_code` is less than 400, False if not.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  text
#  |      Content of the response, in unicode.
#  |
#  |      If Response.encoding is None, encoding will be guessed using
#  |      ``chardet``.
#  |
#  |      The encoding of the response content is determined based solely on HTTP
#  |      headers, following RFC 2616 to the letter. If you can take advantage of
#  |      non-HTTP knowledge to make a better guess at the encoding, you should
#  |      set ``r.encoding`` appropriately before accessing this property.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __attrs__ = ['_content', 'status_code', 'headers', 'url', 'history', '...

# %%
response_data = response.json()
print(response_data["access_token"])
response_data["access_token"]
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDg4MDE2NiwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiOWQwNmU4MGEtZDA0My00ZGUwLWFiYmQtZDg0MTkxZDViMjY1IiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.0CcHnG-ahPftyQwR0JVhEeQqPH_DdTQ7ORu4RZh_X_4
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDg4MDE2NiwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiOWQwNmU4MGEtZDA0My00ZGUwLWFiYmQtZDg0MTkxZDViMjY1IiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.0CcHnG-ahPftyQwR0JVhEeQqPH_DdTQ7ORu4RZh_X_4'

# %%
response_data.keys()
# Out:
# dict_keys(['access_token', 'token_type', 'expires_in', 'scope', 'jti'])

# %%
response_data['token_type']
# Out:
# 'bearer'

# %%
#3
token = response_data['access_token'] # Descomentar cuando necesitas otro token
token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDg4MDE2NiwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiOWQwNmU4MGEtZDA0My00ZGUwLWFiYmQtZDg0MTkxZDViMjY1IiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.0CcHnG-ahPftyQwR0JVhEeQqPH_DdTQ7ORu4RZh_X_4'

# %%
seconds = datetime.timedelta(seconds=response_data['expires_in'])
# timedelta > incremento de tiempo 

#token_exp = (datetime.datetime.now() + seconds)

print("token: " + token + "\n")
print("seconds: " + str(seconds) + "\n")
# Out:
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDg4MDE2NiwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiOWQwNmU4MGEtZDA0My00ZGUwLWFiYmQtZDg0MTkxZDViMjY1IiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.0CcHnG-ahPftyQwR0JVhEeQqPH_DdTQ7ORu4RZh_X_4
#
# seconds: 11:59:59

# %%
print("now() es: " + str(type(datetime.datetime.now())) + "\ny seconds es: " + str(type(seconds)))
# Out:
# now() es: <class 'datetime.datetime'>
# y seconds es: <class 'datetime.timedelta'>

# %%
# Información de datetime: https://medium.com/python-pandemonium/datetime-datetime-seconds-8c76c5ace3d2
ahora = datetime.datetime.now()
expires_in = seconds + ahora

print("datetime: " + str(expires_in))

seconds.total_seconds() #segundos disponibles de conexión
# Out:
# datetime: 2020-05-31 01:08:53.748542
# 43199.0

# %%
data = {'center': '41.394554,2.175153',
        'distance': 10000,
        'operation': 'sale',
        'propertyType': 'homes',
        'locale': 'en',
        'maxItems': 50,
        'order': 'publicationDate',
        'numPage': 0,                # change this number for each request
        'sort': 'desc'} 

data1 = {'center': '38.890891,-6.999911', # Badajoz
        'distance': 10000, # 10km
        'operation': 'sale', # sale o rent
        'propertyType': 'homes', # homes, offices, premises, garages, bedrooms
        'locale': 'en', # es, it, pt, en, ca
        'maxItems': 50,
        'order': 'priceDown',
        'numPage': 0,  # change this number for each request
        'sort': 'desc'} 
data
data1
# Out:
# {'center': '38.890891,-6.999911',
#  'distance': 10000,
#  'operation': 'sale',
#  'propertyType': 'homes',
#  'locale': 'en',
#  'maxItems': 50,
#  'order': 'priceDown',
#  'numPage': 0,
#  'sort': 'desc'}

# %%
# "https://api.idealista.com/3.5/{country}/search"

# url = api_base_url.format(country = "es")
# url = api_base_url.format(country = "pt")
# url = api_base_url.format(country = "it")

url = "https://api.idealista.com/3.5/es/search"

headers = {'Authorization': 'Bearer ' + token}
response_post = requests.post(url,
                         headers=headers,
                         data=data1) # data = dictionario de datos/filtros
# response_post.json()

# %%
# Único código a ejecutar para nuevas búsquedas

response_post = requests.post(url,
                         headers=headers,
                         data=data1) # cambiar con diccionario de datos
response_post
# Out:
# <Response [200]>

# %%
response_post.json()
# Out:
# {'elementList': [{'propertyCode': '89460691',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/1c/fe/cd/771901188.jpg',
#    'externalReference': '392156',
#    'numPhotos': 8,
#    'floor': '3',
#    'price': 79000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 109.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Calle Francisco Pedraja Muñoz',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Avda. Elvas',
#    'country': 'es',
#    'latitude': 38.8820522,
#    'longitude': -6.9885653,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/89460691/',
#    'distance': '1389',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 725.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Avda. Elvas, Badajoz',
#     'title': 'Flat in Calle Francisco Pedraja Muñoz'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '37909782',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/21/47/75/628903473.jpg',
#    'externalReference': 'SRB_HAYA_643975',
#    'numPhotos': 30,
#    'floor': '6',
#    'price': 80000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 145.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'El Fresno no number',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Ciudad Jardín',
#    'country': 'es',
#    'latitude': 38.8680237,
#    'longitude': -6.9669619,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/37909782/',
#    'distance': '3820',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 552.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Ciudad Jardín, Badajoz',
#     'title': 'Flat in El Fresno no number'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '83935208',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/2d/8e/e9/628901984.jpg',
#    'externalReference': 'SRB_HAYA_674518',
#    'numPhotos': 30,
#    'floor': '7',
#    'price': 83000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 145.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'El Fresno no number',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Ciudad Jardín',
#    'country': 'es',
#    'latitude': 38.8680237,
#    'longitude': -6.9669619,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/83935208/',
#    'distance': '3820',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 572.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Ciudad Jardín, Badajoz',
#     'title': 'Flat in El Fresno no number'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88204578',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/bf/9d/66/741310601.jpg',
#    'numPhotos': 22,
#    'price': 450000.0,
#    'propertyType': 'countryHouse',
#    'operation': 'sale',
#    'size': 280.0,
#    'exterior': False,
#    'rooms': 6,
#    'bathrooms': 3,
#    'address': 'Carretera Sevilla KM 9 no number',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Ctra de Sevilla - Ronda sur',
#    'country': 'es',
#    'latitude': 38.8401948,
#    'longitude': -6.9287405,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/88204578/',
#    'distance': '8351',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1607.0,
#    'detailedType': {'typology': 'countryHouse', 'subTypology': 'countryHouse'},
#    'suggestedTexts': {'subtitle': 'Ctra de Sevilla - Ronda sur, Badajoz',
#     'title': 'Estate in Carretera Sevilla KM 9 no number'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88033513',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/9b/d9/25/770740315.jpg',
#    'externalReference': 'NEO0193',
#    'numPhotos': 3,
#    'floor': 'bj',
#    'price': 140000.0,
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 250.0,
#    'exterior': False,
#    'rooms': 9,
#    'bathrooms': 4,
#    'address': 'Calle San Pedro de Alcántara',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Casco Antiguo - Centro',
#    'country': 'es',
#    'latitude': 38.8819574,
#    'longitude': -6.9686684,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88033513/',
#    'distance': '2880',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'priceByArea': 560.0,
#    'detailedType': {'typology': 'chalet'},
#    'suggestedTexts': {'subtitle': 'Casco Antiguo - Centro, Badajoz',
#     'title': 'House in Calle San Pedro de Alcántara'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88406296',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/3e/3f/96/745974681.jpg',
#    'externalReference': 'D04200032',
#    'numPhotos': 24,
#    'floor': '5',
#    'price': 221800.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 122.0,
#    'exterior': True,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle Francisco Crespo Marchirant',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8718481,
#    'longitude': -6.9735997,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88406296/',
#    'distance': '3109',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1818.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat in Calle Francisco Crespo Marchirant'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '85064108',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/cb/91/02/763891010.jpg',
#    'externalReference': '000402',
#    'numPhotos': 18,
#    'floor': '1',
#    'price': 115000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 78.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'San Roque - Ronda norte',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'San Roque - Ronda norte',
#    'country': 'es',
#    'latitude': 38.8807949,
#    'longitude': -6.9581331,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/85064108/',
#    'distance': '3786',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1474.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Roque - Ronda norte, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '33130010',
#    'externalReference': 'SRB_SOLVIA_101008',
#    'numPhotos': 0,
#    'floor': '2',
#    'price': 119000.0,
#    'propertyType': 'duplex',
#    'operation': 'sale',
#    'size': 149.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Avenida Manuel Rojas Torres, 30',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'San Roque - Ronda norte',
#    'country': 'es',
#    'latitude': 38.8824656,
#    'longitude': -6.9587526,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/33130010/',
#    'distance': '3683',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 799.0,
#    'detailedType': {'typology': 'flat', 'subTypology': 'duplex'},
#    'suggestedTexts': {'subtitle': 'San Roque - Ronda norte, Badajoz',
#     'title': 'Duplex in Avenida Manuel Rojas Torres, 30'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88982915',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/1d/dd/5a/760304200.jpg',
#    'numPhotos': 65,
#    'price': 240000.0,
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 300.0,
#    'exterior': False,
#    'rooms': 9,
#    'bathrooms': 3,
#    'address': 'Carretera de Olivenza',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'El Plantío - Corazón de Jesús',
#    'country': 'es',
#    'latitude': 38.8591184,
#    'longitude': -6.9901781,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88982915/',
#    'distance': '3631',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 800.0,
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'El Plantío - Corazón de Jesús, Badajoz',
#     'title': 'Detached house in Carretera de Olivenza'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88028202',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/0a/92/97/736803491.jpg',
#    'numPhotos': 30,
#    'floor': 'bj',
#    'price': 87000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 90.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Avenida Felipe Trigo',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Ctra de Sevilla - Ronda sur',
#    'country': 'es',
#    'latitude': 38.8710713,
#    'longitude': -6.9587394,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88028202/',
#    'distance': '4189',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 967.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Ctra de Sevilla - Ronda sur, Badajoz',
#     'title': 'Flat in Avenida Felipe Trigo'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '83893785',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/45/2b/3d/763888438.jpg',
#    'externalReference': '000400',
#    'numPhotos': 20,
#    'price': 181300.0,
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 180.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 3,
#    'address': 'Las Vaguadas',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Las Vaguadas',
#    'country': 'es',
#    'latitude': 38.8513,
#    'longitude': -6.96837,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/83893785/',
#    'distance': '5180',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1007.0,
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Las Vaguadas, Badajoz',
#     'title': 'Detached house'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88716455',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/7e/60/05/753459778.jpg',
#    'externalReference': 'PIS_171',
#    'numPhotos': 21,
#    'floor': '2',
#    'price': 150000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 104.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Avenida Sinforiano Madroñero',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Huerta Rosales - Valdepasillas',
#    'country': 'es',
#    'latitude': 38.8705982,
#    'longitude': -6.9915271,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88716455/',
#    'distance': '2370',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1442.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Huerta Rosales - Valdepasillas, Badajoz',
#     'title': 'Flat in Avenida Sinforiano Madroñero'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '84266170',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/37/79/d6/771626817.jpg',
#    'externalReference': '1302',
#    'numPhotos': 17,
#    'floor': 'bj',
#    'price': 115000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 132.0,
#    'exterior': True,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': 'Av/ Santa Marina',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8729879,
#    'longitude': -6.9767715,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/84266170/',
#    'distance': '2823',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 871.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat in Av/ Santa Marina'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88699728',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/31/5f/df/767710644.jpg',
#    'externalReference': '247516',
#    'numPhotos': 20,
#    'floor': '1',
#    'price': 97000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 90.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle Canarias',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'La Estación',
#    'country': 'es',
#    'latitude': 38.8866077,
#    'longitude': -6.9820901,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88699728/',
#    'distance': '1614',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1078.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'La Estación, Badajoz',
#     'title': 'Flat in Calle Canarias'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87004488',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/27/28/92/708441354.jpg',
#    'externalReference': '267',
#    'numPhotos': 15,
#    'floor': '1',
#    'price': 97000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 80.0,
#    'exterior': False,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'San Roque - Ronda norte',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'San Roque - Ronda norte',
#    'country': 'es',
#    'latitude': 38.8812059,
#    'longitude': -6.9525033,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87004488/',
#    'distance': '4242',
#    'hasVideo': False,
#    'status': 'renew',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1213.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Roque - Ronda norte, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87512377',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/51/68/69/770967445.jpg',
#    'externalReference': 'NEO0165',
#    'numPhotos': 23,
#    'floor': '3',
#    'price': 175000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 129.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Zurbaran',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Casco Antiguo - Centro',
#    'country': 'es',
#    'latitude': 38.876809,
#    'longitude': -6.971882,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87512377/',
#    'distance': '2887',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1357.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Casco Antiguo - Centro, Badajoz',
#     'title': 'Flat in Zurbaran'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87151614',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/2c/2d/fe/712974245.jpg',
#    'externalReference': 'V3737',
#    'numPhotos': 17,
#    'floor': '5',
#    'price': 140000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 88.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Pardaleras',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Pardaleras',
#    'country': 'es',
#    'latitude': 38.8720739,
#    'longitude': -6.9733485,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87151614/',
#    'distance': '3108',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1591.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Pardaleras, Badajoz', 'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '86073003',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/7a/07/bd/682844235.jpg',
#    'numPhotos': 32,
#    'price': 360000.0,
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 189.0,
#    'exterior': False,
#    'rooms': 2,
#    'bathrooms': 3,
#    'address': 'Carretera Olivenza no number',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Huerta Rosales - Valdepasillas',
#    'country': 'es',
#    'latitude': 38.8616352,
#    'longitude': -6.9859218,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/86073003/',
#    'distance': '3471',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1905.0,
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Huerta Rosales - Valdepasillas, Badajoz',
#     'title': 'Detached house in Carretera Olivenza no number'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '86145926',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/32/e0/bd/763880473.jpg',
#    'externalReference': '000550',
#    'numPhotos': 20,
#    'price': 135000.0,
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 100.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'El Plantío - Corazón de Jesús',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'El Plantío - Corazón de Jesús',
#    'country': 'es',
#    'latitude': 38.83175,
#    'longitude': -7.02332,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/86145926/',
#    'distance': '6881',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'priceByArea': 1350.0,
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'El Plantío - Corazón de Jesús, Badajoz',
#     'title': 'Detached house'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87895628',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/a6/f4/6b/763888290.jpg',
#    'externalReference': '000886',
#    'numPhotos': 20,
#    'floor': '1',
#    'price': 141000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 100.0,
#    'exterior': True,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Ciudad Jardín',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Ciudad Jardín',
#    'country': 'es',
#    'latitude': 38.8706035,
#    'longitude': -6.9687115,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87895628/',
#    'distance': '3518',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1410.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Ciudad Jardín, Badajoz', 'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87237139',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/30/aa/38/763891313.jpg',
#    'externalReference': '000099',
#    'numPhotos': 16,
#    'floor': 'bj',
#    'price': 121000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 130.0,
#    'exterior': True,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': 'Santa Marina - La Paz',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8746594,
#    'longitude': -6.9762754,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87237139/',
#    'distance': '2728',
#    'hasVideo': False,
#    'status': 'renew',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 931.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88162738',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/89/ee/dc/740273296.jpg',
#    'externalReference': 'PIS_89',
#    'numPhotos': 16,
#    'floor': '1',
#    'price': 205000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 140.0,
#    'exterior': False,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': 'Plaza de la Constitución',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8714429,
#    'longitude': -6.9741307,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88162738/',
#    'distance': '3107',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1464.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat in Plaza de la Constitución'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '39609497',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e5/5d/9e/744220334.jpg',
#    'externalReference': 'BJ Solano Figueroa',
#    'numPhotos': 41,
#    'price': 105000.0,
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 80.0,
#    'exterior': False,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'SOLANO DE FIGUEROA, 28',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'San Roque - Ronda norte',
#    'country': 'es',
#    'latitude': 38.8774099,
#    'longitude': -6.9586445,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/39609497/',
#    'distance': '3873',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'priceByArea': 1313.0,
#    'detailedType': {'typology': 'chalet', 'subTypology': 'terracedHouse'},
#    'suggestedTexts': {'subtitle': 'San Roque - Ronda norte, Badajoz',
#     'title': 'Terraced house in SOLANO DE FIGUEROA, 28'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '86476862',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d1/02/5d/694599529.jpg',
#    'numPhotos': 39,
#    'price': 720000.0,
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 550.0,
#    'exterior': False,
#    'rooms': 7,
#    'bathrooms': 5,
#    'address': 'vaguadas no number',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Las Vaguadas',
#    'country': 'es',
#    'latitude': 38.8453058,
#    'longitude': -6.9686097,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/86476862/',
#    'distance': '5747',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1309.0,
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Las Vaguadas, Badajoz',
#     'title': 'Detached house in vaguadas no number'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '85928278',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/ef/54/41/679367480.jpg',
#    'externalReference': '01195249',
#    'numPhotos': 36,
#    'floor': '4',
#    'price': 249990.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 191.0,
#    'exterior': True,
#    'rooms': 5,
#    'bathrooms': 3,
#    'address': 'Calle Díaz Brito',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8709074,
#    'longitude': -6.9787854,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/85928278/',
#    'distance': '2877',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1309.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat in Calle Díaz Brito'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87332764',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d4/73/1e/717981308.jpg',
#    'externalReference': 'D04198973',
#    'numPhotos': 16,
#    'floor': '1',
#    'price': 139900.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 110.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Avenida Sinforiano Madroñero',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Huerta Rosales - Valdepasillas',
#    'country': 'es',
#    'latitude': 38.8661861,
#    'longitude': -6.9848737,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87332764/',
#    'distance': '3039',
#    'hasVideo': False,
#    'status': 'renew',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1272.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Huerta Rosales - Valdepasillas, Badajoz',
#     'title': 'Flat in Avenida Sinforiano Madroñero'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88250923',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/42/e4/70/763875475.jpg',
#    'externalReference': '000029',
#    'numPhotos': 20,
#    'price': 720000.0,
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 550.0,
#    'exterior': False,
#    'rooms': 6,
#    'bathrooms': 5,
#    'address': 'Las Vaguadas',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Las Vaguadas',
#    'country': 'es',
#    'latitude': 38.8407914,
#    'longitude': -6.9682017,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88250923/',
#    'distance': '6210',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1309.0,
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Las Vaguadas, Badajoz',
#     'title': 'Detached house'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88659463',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/25/c9/bf/752080340.jpg',
#    'externalReference': 'BZ-D09371-19',
#    'numPhotos': 24,
#    'floor': '5',
#    'price': 221800.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 122.0,
#    'exterior': True,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Santa Marina - La Paz',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8720302,
#    'longitude': -6.9761292,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88659463/',
#    'distance': '2938',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1818.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '86549884',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/37/57/6c/696132036.jpg',
#    'externalReference': '021926',
#    'numPhotos': 31,
#    'floor': '2',
#    'price': 165000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 72.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'Avda. Elvas',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Avda. Elvas',
#    'country': 'es',
#    'latitude': 38.8838072,
#    'longitude': -6.9874832,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/86549884/',
#    'distance': '1333',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 2292.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Avda. Elvas, Badajoz', 'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88468270',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/bf/28/a9/747484251.jpg',
#    'numPhotos': 14,
#    'floor': '3',
#    'price': 79800.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 75.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'Dotor Flemi no number',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'San Roque - Ronda norte',
#    'country': 'es',
#    'latitude': 38.8754997,
#    'longitude': -6.9567575,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/88468270/',
#    'distance': '4108',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 20000.0},
#    'priceByArea': 1064.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Roque - Ronda norte, Badajoz',
#     'title': 'Flat in Dotor Flemi no number'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '86203987',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/65/7b/93/763888612.jpg',
#    'externalReference': '000409',
#    'numPhotos': 20,
#    'floor': '3',
#    'price': 181000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 110.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Casco Antiguo - Centro',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Casco Antiguo - Centro',
#    'country': 'es',
#    'latitude': 38.8741385,
#    'longitude': -6.9713177,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/86203987/',
#    'distance': '3097',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1645.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Casco Antiguo - Centro, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '86222922',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/01/4e/a3/686844949.jpg',
#    'externalReference': '409',
#    'numPhotos': 27,
#    'floor': '3',
#    'price': 181000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 110.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Casco Antiguo - Centro',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Casco Antiguo - Centro',
#    'country': 'es',
#    'latitude': 38.874009,
#    'longitude': -6.968382,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/86222922/',
#    'distance': '3312',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 20000.0},
#    'priceByArea': 1645.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Casco Antiguo - Centro, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87477384',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/2b/97/59/722542161.jpg',
#    'externalReference': '2012-1738',
#    'numPhotos': 10,
#    'floor': '4',
#    'price': 112500.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 70.0,
#    'exterior': True,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Pardaleras',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Pardaleras',
#    'country': 'es',
#    'latitude': 38.8717901,
#    'longitude': -6.9664818,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87477384/',
#    'distance': '3589',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1607.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Pardaleras, Badajoz', 'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88567847',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/8d/d1/88/749795124.jpg',
#    'numPhotos': 41,
#    'floor': '4',
#    'price': 325000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 179.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'La Bomba',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Pardaleras',
#    'country': 'es',
#    'latitude': 38.8763499,
#    'longitude': -6.9717555,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88567847/',
#    'distance': '2924',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 1816.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Pardaleras, Badajoz',
#     'title': 'Flat in La Bomba'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87477605',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/11/5c/ec/722546974.jpg',
#    'externalReference': '2012-1782',
#    'numPhotos': 18,
#    'floor': '3',
#    'price': 84000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 85.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'La Estación',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'La Estación',
#    'country': 'es',
#    'latitude': 38.8870057,
#    'longitude': -6.9837163,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87477605/',
#    'distance': '1466',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 988.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'La Estación, Badajoz', 'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88136702',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/3e/d9/3a/739575246.jpg',
#    'externalReference': '03051',
#    'numPhotos': 25,
#    'floor': 'bj',
#    'price': 63000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 88.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'La Jara',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Ciudad Jardín',
#    'country': 'es',
#    'latitude': 38.8686546,
#    'longitude': -6.9667882,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88136702/',
#    'distance': '3785',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 716.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Ciudad Jardín, Badajoz',
#     'title': 'Flat in La Jara'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87943978',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/05/62/a4/770740191.jpg',
#    'externalReference': 'NEO0178',
#    'numPhotos': 27,
#    'floor': '3',
#    'price': 118000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 98.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle Marín de Rodezno',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Pardaleras',
#    'country': 'es',
#    'latitude': 38.8732657,
#    'longitude': -6.9667681,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87943978/',
#    'distance': '3474',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1204.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Pardaleras, Badajoz',
#     'title': 'Flat in Calle Marín de Rodezno'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '87377207',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/f5/b2/37/719261990.jpg',
#    'externalReference': 'PIS_41',
#    'numPhotos': 25,
#    'floor': '4',
#    'price': 250000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 190.0,
#    'exterior': True,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': 'Diaz Brito',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8727074,
#    'longitude': -6.9764854,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/87377207/',
#    'distance': '2863',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1316.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat in Diaz Brito'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '85480497',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e5/88/68/693661832.jpg',
#    'externalReference': '03242',
#    'numPhotos': 25,
#    'floor': 'bj',
#    'price': 63000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 88.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle Jara, 60 -72',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Ciudad Jardín',
#    'country': 'es',
#    'latitude': 38.8675969,
#    'longitude': -6.9657575,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/85480497/',
#    'distance': '3930',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 716.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Ciudad Jardín, Badajoz',
#     'title': 'Flat in Calle Jara, 60 -72'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88186137',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c9/7b/b9/763886206.jpg',
#    'externalReference': '000114',
#    'numPhotos': 13,
#    'floor': '1',
#    'price': 136000.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 75.0,
#    'exterior': True,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Santa Marina - La Paz',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8737787,
#    'longitude': -6.9797253,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88186137/',
#    'distance': '2583',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1813.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88917527',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/18/d9/c8/758626495.jpg',
#    'externalReference': 'PIS_200',
#    'numPhotos': 27,
#    'floor': '4',
#    'price': 199500.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 180.0,
#    'exterior': True,
#    'rooms': 4,
#    'bathrooms': 3,
#    'address': 'Avenida de Fernando Calzadilla',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8728429,
#    'longitude': -6.9749307,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88917527/',
#    'distance': '2949',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 1108.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat in Avenida de Fernando Calzadilla'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '89490583',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e2/b7/90/772158903.jpg',
#    'externalReference': '51067162',
#    'numPhotos': 6,
#    'floor': '1',
#    'price': 65100.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 49.0,
#    'exterior': False,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Calle Loly Trabajo',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'San Roque - Ronda norte',
#    'country': 'es',
#    'latitude': 38.8775321,
#    'longitude': -6.9519928,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/89490583/',
#    'distance': '4405',
#    'hasVideo': False,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 1329.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Roque - Ronda norte, Badajoz',
#     'title': 'Flat in Calle Loly Trabajo'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '89195296',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/54/36/91/765596125.jpg',
#    'externalReference': '7261674',
#    'numPhotos': 12,
#    'floor': 'bj',
#    'price': 74600.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 87.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle Vistahermosa, 54',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'San Roque - Ronda norte',
#    'country': 'es',
#    'latitude': 38.8812278,
#    'longitude': -6.9558329,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/89195296/',
#    'distance': '3963',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 857.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Roque - Ronda norte, Badajoz',
#     'title': 'Flat in Calle Vistahermosa, 54'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '89197370',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/fc/a9/8b/765654691.jpg',
#    'externalReference': 'VI-000-030-678-345',
#    'numPhotos': 26,
#    'price': 121500.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 103.0,
#    'exterior': False,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'Santa Marina - La Paz',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.8726577,
#    'longitude': -6.9796562,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/89197370/',
#    'distance': '2680',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'priceByArea': 1180.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88826450',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d0/f3/ba/756369554.jpg',
#    'externalReference': '299',
#    'numPhotos': 25,
#    'floor': '9',
#    'price': 380000.0,
#    'propertyType': 'penthouse',
#    'operation': 'sale',
#    'size': 150.0,
#    'exterior': False,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': 'Santa Marina - La Paz',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Santa Marina - La Paz',
#    'country': 'es',
#    'latitude': 38.87252,
#    'longitude': -6.97102,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88826450/',
#    'distance': '3228',
#    'hasVideo': False,
#    'status': 'renew',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 2533.0,
#    'detailedType': {'typology': 'flat', 'subTypology': 'penthouse'},
#    'suggestedTexts': {'subtitle': 'Santa Marina - La Paz, Badajoz',
#     'title': 'Penthouse'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '88702683',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/5e/ca/bd/753936049.jpg',
#    'externalReference': '29792533',
#    'numPhotos': 10,
#    'price': 103835.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 181.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'San Roque - Ronda norte',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'San Roque - Ronda norte',
#    'country': 'es',
#    'latitude': 38.8807361,
#    'longitude': -6.9570905,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/88702683/',
#    'distance': '3874',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 574.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'San Roque - Ronda norte, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '32536291',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/26/bb/98/137173922.jpg',
#    'externalReference': '42519399',
#    'numPhotos': 12,
#    'price': 89110.0,
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 121.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Pedanías norte',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Pedanías norte',
#    'country': 'es',
#    'latitude': 38.9193806,
#    'longitude': -6.9350659,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/32536291/',
#    'distance': '6443',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'priceByArea': 736.0,
#    'detailedType': {'typology': 'chalet'},
#    'suggestedTexts': {'subtitle': 'Pedanías norte, Badajoz', 'title': 'House'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '82053509',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d4/c2/c3/590437689.jpg',
#    'externalReference': '46335241',
#    'numPhotos': 10,
#    'price': 36670.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 109.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Casco Antiguo - Centro',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Casco Antiguo - Centro',
#    'country': 'es',
#    'latitude': 38.8803618,
#    'longitude': -6.9720238,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/82053509/',
#    'distance': '2682',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 336.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Casco Antiguo - Centro, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '82053508',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/38/c0/1a/590437666.jpg',
#    'externalReference': '46335299',
#    'numPhotos': 19,
#    'price': 36670.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 88.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Casco Antiguo - Centro',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Casco Antiguo - Centro',
#    'country': 'es',
#    'latitude': 38.8826618,
#    'longitude': -6.9713238,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/82053508/',
#    'distance': '2637',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 417.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Casco Antiguo - Centro, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False},
#   {'propertyCode': '89108811',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/40/6b/e6/763781107.jpg',
#    'externalReference': '52447177',
#    'numPhotos': 9,
#    'price': 79800.0,
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 61.0,
#    'exterior': False,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Casco Antiguo - Centro',
#    'province': 'Badajoz',
#    'municipality': 'Badajoz',
#    'district': 'Casco Antiguo - Centro',
#    'country': 'es',
#    'latitude': 38.8773989,
#    'longitude': -6.9645532,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/89108811/',
#    'distance': '3408',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'hasLift': False,
#    'priceByArea': 1308.0,
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Casco Antiguo - Centro, Badajoz',
#     'title': 'Flat'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False,
#    'topNewDevelopment': False}],
#  'total': 1599,
#  'totalPages': 32,
#  'actualPage': 1,
#  'itemsPerPage': 50,
#  'numPaginations': 0,
#  'hiddenResults': False,
#  'summary': ['Buy',
#   'Homes',
#   'district Avda. Elvas, Badajoz',
#   'All prices',
#   'All sizes'],
#  'paginable': True,
#  'upperRangePosition': 50,
#  'lowerRangePosition': 0}

# %%
# Pandas

# %%
import pandas as pd

# %%
type(response_post.json())
# Out:
# dict

# %%
values = my_dict.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-2b6f54561918> in <module>
# ----> 1 values = my_dict.values()
#
# NameError: name 'my_dict' is not defined

# %%
my_dict = response_post.json()
keys = my_dict.keys()
keys
# Out:
# dict_keys(['elementList', 'total', 'totalPages', 'actualPage', 'itemsPerPage', 'numPaginations', 'hiddenResults', 'summary', 'paginable', 'upperRangePosition', 'lowerRangePosition'])

# %%
dict0 = my_dict['elementList'][0]
dict0.keys()
# Out:
# dict_keys(['propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor', 'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms', 'bathrooms', 'address', 'province', 'municipality', 'district', 'country', 'latitude', 'longitude', 'showAddress', 'url', 'distance', 'hasVideo', 'status', 'newDevelopment', 'hasLift', 'priceByArea', 'detailedType', 'suggestedTexts', 'hasPlan', 'has3DTour', 'has360', 'topNewDevelopment'])

# %%
dict0.values()
# Out:
# dict_values(['89460691', 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/1c/fe/cd/771901188.jpg', '392156', 8, '3', 79000.0, 'flat', 'sale', 109.0, False, 3, 2, 'Calle Francisco Pedraja Muñoz', 'Badajoz', 'Badajoz', 'Avda. Elvas', 'es', 38.8820522, -6.9885653, False, 'https://www.idealista.com/inmueble/89460691/', '1389', False, 'good', False, True, 725.0, {'typology': 'flat'}, {'subtitle': 'Avda. Elvas, Badajoz', 'title': 'Flat in Calle Francisco Pedraja Muñoz'}, False, False, False, False])

# %%
dict0['size']
# Out:
# 109.0

# %%
df = pd.DataFrame.from_dict(my_dict)
# Esto falla por diferencia de tamaños de arrays en diccionario

# %%
my_dict.items()
# Out:
# dict_items([('elementList', [{'propertyCode': '89460691', 'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/1c/fe/cd/771901188.jpg', 'externalReference': '392156', 'numPhotos': 8, 'floor': '3', 'price': 79000.0, 'propertyType': 'flat', 'operation': 'sale', 'size': 109.0, 'exterior': False, 'rooms': 3, 'bathrooms': 2, 'address': 'Calle Francisco Pedraja Muñoz', 'province': 'Badajoz', 'municipality': 'Badajoz', 'district': 'Avda. Elvas', 'country': 'es', 'latitude': 38.8820522, 'longitude': -6.9885653, 'showAddress': False, 'url': 'https://www.idealista.com/inmueble/89460691/', 'distance': '1389', 'hasVideo': False, 'status': 'good', 'newDevelopment': False, 'hasLift': True, 'priceByArea': 725.0, 'detailedType': {'typology': 'flat'}, 'suggestedTexts': {'subtitle': 'Avda. Elvas, Badajoz', 'title': 'Flat in Calle Francisco Pedraja Muñoz'}, 'hasPlan': False, 'has3DTour': False, 'has360': False, 'topNewDevelopment': False}, {'propertyCode': '37909782', 'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/21/47/75/628903473.jpg', 'externalReference': 'SRB_HAYA_643975', 'numPhotos': 30, 'floor': '6', 'price': 80000.0, 'propertyType': 'flat', 'operation': 'sale', 'size': 145.0, 'exterior': False, 'rooms': 4, 'bathrooms': 2, 'address': 'El Fresno no number', 'province': 'Badajoz', 'municipality': 'Badajoz', 'district': 'Ciudad Jardín', 'country': 'es', 'latitude': 38.8680237, 'longitude': -6.9669619, 'showAddress': True, 'url': 'https://www.idealista.com/inmueble/37909782/', 'distance': '3820', 'hasVideo': False, 'newDevelopment': False, 'hasLift': True, 'parkingSpace': {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}, 'priceByArea': 552.0, 'detailedType': {'typology': 'flat'}, 'suggestedTexts': {'subtitle': 'Ciudad Jardín, Badajoz', 'title': 'Flat in El Fresno no number'}, 'hasPlan': False, 'has3DTour': False, 'has360': False, 'topNewDevelopment': False}, {'propertyCode': '83935208', 'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/2d/8e/e9/628901984.jpg', 'externalReference': 'SRB_HAYA_674518', 'numPhotos': 30, 'floor': '7', 'price': 83000.0, 'propertyType': 'flat', 'operation': 'sale', 'size': 145.0, 'exterior': False, 'rooms': 4, 'bathrooms': 2, 'address': 'El Fresno no number', 'province': 'Badajoz', 'municipality': 'Badajoz', 'district': 'Ciudad Jardín', 'country': 'es', 'latitude': 38.8680237, 'longitude': -6.9669619, 'showAddress': True, 'url': 'https://www.idealista.com/inmueble/83935208/', 'distance': '3820', 'hasVideo': False, 'newDevelopment': False, 'hasLift': True, 'parkingSpace': {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}, 'priceByArea': 572.0, 'detailedType': {'typology': 'flat'}, 'suggestedTexts': {'subtitle': 'Ciudad Jardín, Badajoz', 'title': 'Flat in El Fresno no number'}, 'hasPlan': False, 'has3DTour': False, 'has360': False, 'topNewDevelopment': False}, {'propertyCode': '88204578', 'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/bf/9d/66/741310601.jpg', 'numPhotos': 22, 'price': 450000.0, 'propertyType': 'countryHouse', 'operation': 'sale', 'size': 280.0, 'exterior': False, 'rooms': 6, 'bathrooms': 3, 'address': 'Carretera Sevilla KM 9 no number', 'province': 'Badajoz', 'municipality': 'Badajoz', 'district': 'Ctra de Sevilla - Ronda sur', 'country': 'es', 'latitude': 38.8401948, 'longitude': -6.9287405, 'showAddress': True, 'url': 'https://www.idealista.com/inmueble/88204578/', 'distance': '8351', 'hasVideo': False, 'status': 'good', 'newDevelopment': False, 'parkingSpace': {'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}, 'priceByArea': 1607.0, 'detailedType': {'typology': 'countryHouse', 'subTypology': 'countryHouse'}, 'suggestedTexts': {'subtitle': 'Ctra de Sevilla - Ronda sur, Badajoz', 'title': 'Estate in Carretera Sevilla KM 9 no number'}, 'hasPlan': False, 'has3DTour': False, 'has360': False, 'topNewDevelopment': False}, {'pr ...

# %%
pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in my_dict.items() ]))
# Out:
#                                           elementList   total  totalPages  \
# 0   {'propertyCode': '89460691', 'thumbnail': 'htt...  1599.0        32.0
# 1   {'propertyCode': '37909782', 'thumbnail': 'htt...     NaN         NaN
# 2   {'propertyCode': '83935208', 'thumbnail': 'htt...     NaN         NaN
# 3   {'propertyCode': '88204578', 'thumbnail': 'htt...     NaN         NaN
# 4   {'propertyCode': '88033513', 'thumbnail': 'htt...     NaN         NaN
# 5   {'propertyCode': '88406296', 'thumbnail': 'htt...     NaN         NaN
# 6   {'propertyCode': '85064108', 'thumbnail': 'htt...     NaN         NaN
# 7   {'propertyCode': '33130010', 'externalReferenc...     NaN         NaN
# 8   {'propertyCode': '88982915', 'thumbnail': 'htt...     NaN         NaN
# 9   {'propertyCode': '88028202', 'thumbnail': 'htt...     NaN         NaN
# 10  {'propertyCode': '83893785', 'thumbnail': 'htt...     NaN         NaN
# 11  {'propertyCode': '88716455', 'thumbnail': 'htt...     NaN         NaN
# 12  {'propertyCode': '84266170', 'thumbnail': 'htt...     NaN         NaN
# 13  {'propertyCode': '88699728', 'thumbnail': 'htt...     NaN         NaN
# 14  {'propertyCode': '87004488', 'thumbnail': 'htt...     NaN         NaN
# 15  {'propertyCode': '87512377', 'thumbnail': 'htt...     NaN         NaN
# 16  {'propertyCode': '87151614', 'thumbnail': 'htt...     NaN         NaN
# 17  {'propertyCode': '86073003', 'thumbnail': 'htt...     NaN         NaN
# 18  {'propertyCode': '86145926', 'thumbnail': 'htt...     NaN         NaN
# 19  {'propertyCode': '87895628', 'thumbnail': 'htt...     NaN         NaN
# 20  {'propertyCode': '87237139', 'thumbnail': 'htt...     NaN         NaN
# 21  {'propertyCode': '88162738', 'thumbnail': 'htt...     NaN         NaN
# 22  {'propertyCode': '39609497', 'thumbnail': 'htt...     NaN         NaN
# 23  {'propertyCode': '86476862', 'thumbnail': 'htt...     NaN         NaN
# 24  {'propertyCode': '85928278', 'thumbnail': 'htt...     NaN         NaN
# 25  {'propertyCode': '87332764', 'thumbnail': 'htt...     NaN         NaN
# 26  {'propertyCode': '88250923', 'thumbnail': 'htt...     NaN         NaN
# 27  {'propertyCode': '88659463', 'thumbnail': 'htt...     NaN         NaN
# 28  {'propertyCode': '86549884', 'thumbnail': 'htt...     NaN         NaN
# 29  {'propertyCode': '88468270', 'thumbnail': 'htt...     NaN         NaN
# 30  {'propertyCode': '86203987', 'thumbnail': 'htt...     NaN         NaN
# 31  {'propertyCode': '86222922', 'thumbnail': 'htt...     NaN         NaN
# 32  {'propertyCode': '87477384', 'thumbnail': 'htt...     NaN         NaN
# 33  {'propertyCode': '88567847', 'thumbnail': 'htt...     NaN         NaN
# 34  {'propertyCode': '87477605', 'thumbnail': 'htt...     NaN         NaN
# 35  {'propertyCode': '88136702', 'thumbnail': 'htt...     NaN         NaN
# 36  {'propertyCode': '87943978', 'thumbnail': 'htt...     NaN         NaN
# 37  {'propertyCode': '87377207', 'thumbnail': 'htt...     NaN         NaN
# 38  {'propertyCode': '85480497', 'thumbnail': 'htt...     NaN         NaN
# 39  {'propertyCode': '88186137', 'thumbnail': 'htt...     NaN         NaN
# 40  {'propertyCode': '88917527', 'thumbnail': 'htt...     NaN         NaN
# 41  {'propertyCode': '89490583', 'thumbnail': 'htt...     NaN         NaN
# 42  {'propertyCode': '89195296', 'thumbnail': 'htt...     NaN         NaN
# 43  {'propertyCode': '89197370', 'thumbnail': 'htt...     NaN         NaN
# 44  {'propertyCode': '88826450', 'thumbnail': 'htt...     NaN         NaN
# 45  {'propertyCode': '88702683', 'thumbnail': 'htt...     NaN         NaN
# 46  {'propertyCode': '32536291', 'thumbnail': 'htt...     NaN         NaN
# 47  {'propertyCode': '82053509', 'thumbnail': 'htt...     NaN         NaN
# 48  {'propertyCode': '82053508', 'thumbnail': 'htt...     NaN         NaN
# 49  {'propertyCode': '89108811', 'thumbnail': 'htt...     NaN         NaN
#
#     actualPage  itemsPerPage  numPaginations hiddenResults  \
# 0          1.0          50.0             0.0         False
# 1          NaN           NaN             NaN           NaN
# 2          NaN           NaN             NaN           NaN
# 3          NaN           NaN             NaN           NaN
# 4          NaN           NaN             NaN           NaN
# 5          NaN           NaN             NaN           NaN
# 6          NaN           NaN             NaN           NaN
# 7          NaN           NaN             NaN           NaN
# 8          NaN           NaN             NaN           NaN
# 9          NaN           NaN             NaN           NaN
# 10         NaN           NaN             NaN           NaN
# 11         NaN           NaN             NaN           NaN
# 12         NaN           NaN             NaN           NaN
# 13         NaN           NaN             NaN           NaN
# 14         NaN           NaN             NaN           NaN
# 15         NaN           NaN             NaN           NaN
# 16         NaN           NaN             NaN           NaN
# 17         NaN           NaN             NaN           NaN
# 18         NaN           NaN             NaN           NaN
# 19         NaN           NaN             NaN           NaN
# 20         NaN           NaN             NaN           NaN
# 21         NaN           NaN             NaN           NaN
# 22         NaN           NaN             NaN           NaN
# 23         NaN           NaN             NaN           NaN
# 24         NaN           NaN             NaN           NaN
# 25         NaN           NaN             NaN           NaN
# 26         NaN           NaN             NaN           NaN
# 27         NaN           NaN             NaN           NaN
# 28         NaN           NaN             NaN           NaN
# 29         NaN           NaN             NaN           NaN
# 30         NaN           NaN             NaN           NaN
# 31         NaN           NaN             NaN           NaN
# 32         NaN           NaN             NaN           NaN
# 33         NaN           NaN             NaN           NaN
# 34         NaN           NaN             NaN           NaN
# 35         NaN           NaN             NaN           NaN
# 36         NaN           NaN             NaN           NaN
# 37         NaN           NaN             NaN           NaN
# 38         NaN           NaN             NaN           NaN
# 39         NaN           NaN             NaN           NaN
# 40         NaN           NaN             NaN           NaN
# 41         NaN           NaN             NaN           NaN
# 42         NaN           NaN             NaN           NaN
# 43         NaN           NaN             NaN           NaN
# 44         NaN           NaN             NaN           NaN
# 45         NaN           NaN             NaN           NaN
# 46         NaN           NaN             NaN           NaN
# 47         NaN           NaN             NaN           NaN
# 48         NaN           NaN             NaN           NaN
# 49         NaN           NaN             NaN           NaN
#
#                           summary paginable  upperRangePosition  \
# 0                             Buy      True                50.0
# 1                           Homes       NaN                 NaN
# 2   district Avda. Elvas, Badajoz       NaN                 NaN
# 3                      All prices       NaN                 NaN
# 4                       All sizes       NaN                 NaN
# 5                             NaN       NaN                 NaN
# 6                             NaN       NaN                 NaN
# 7                             NaN       NaN                 NaN
# 8                             NaN       NaN                 NaN
# 9                             NaN       NaN                 NaN
# 10                            NaN       NaN                 NaN
# 11                            NaN       NaN                 NaN
# 12                            NaN       NaN                 NaN
# 13                            NaN       NaN                 NaN
# 14                            NaN       NaN                 NaN
# 15                            NaN       NaN                 NaN
# 16                            NaN       NaN                 NaN
# 17                            NaN       NaN                 NaN
# 18                            NaN       NaN                 NaN
# 19                            NaN       NaN                 NaN
# 20                            NaN       NaN                 NaN
# 21                            NaN       NaN                 NaN
# 22                            NaN       NaN                 NaN
# 23                            NaN       NaN                 NaN
# 24                            NaN       NaN                 NaN
# 25                            NaN       NaN                 NaN
# 26                            NaN       NaN                 NaN
# 27                            NaN       NaN                 NaN
# 28                            NaN       NaN                 NaN
# 29                            NaN       NaN                 NaN
# 30                            NaN       NaN                 NaN
# 31                            NaN       NaN                 NaN
# 32                            NaN       NaN                 NaN
# 33                            NaN       NaN                 NaN
# 34                            NaN       NaN                 NaN
# 35                            NaN       NaN                 NaN
# 36                            NaN       NaN                 NaN
# 37                            NaN       NaN                 NaN
# 38                            NaN       NaN                 NaN
# 39                            NaN       NaN                 NaN
# 40                            NaN       NaN                 NaN
# 41                            NaN       NaN                 NaN
# 42                            NaN       NaN                 NaN
# 43                            NaN       NaN                 NaN
# 44                            NaN       NaN                 NaN
# 45                            NaN       NaN                 NaN
# 46                            NaN       NaN                 NaN
# 47                            NaN       NaN                 NaN
# 48                            NaN       NaN                 NaN
# 49                            NaN       NaN                 NaN
#
#     lowerRangePosition
# 0                  0.0
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                 NaN
# 33                 NaN
# 34                 NaN
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38                 NaN
# 39                 NaN
# 40                 NaN
# 41                 NaN
# 42                 NaN
# 43                 NaN
# 44                 NaN
# 45                 NaN
# 46                 NaN
# 47                 NaN
# 48                 NaN
# 49                 NaN

# %%
dict0 = my_dict['elementList'][0]
df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in dict0.items() ]))
df
# size price hasLift
# Out:
# C:\Users\Usuario\Anaconda\lib\site-packages\pandas\core\frame.py:7397: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   index = _union_indexes(indexes)
# C:\Users\Usuario\Anaconda\lib\site-packages\pandas\core\indexes\api.py:107: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
#          propertyCode                                          thumbnail  \
# 0            89460691  https://img3.idealista.com/blur/WEB_LISTING/0/...
# typology          NaN                                                NaN
# subtitle          NaN                                                NaN
# title             NaN                                                NaN
#
#          externalReference  numPhotos floor    price propertyType operation  \
# 0                   392156        8.0     3  79000.0         flat      sale
# typology               NaN        NaN   NaN      NaN          NaN       NaN
# subtitle               NaN        NaN   NaN      NaN          NaN       NaN
# title                  NaN        NaN   NaN      NaN          NaN       NaN
#
#            size exterior        ...         status  newDevelopment hasLift  \
# 0         109.0    False        ...           good           False    True
# typology    NaN      NaN        ...            NaN             NaN     NaN
# subtitle    NaN      NaN        ...            NaN             NaN     NaN
# title       NaN      NaN        ...            NaN             NaN     NaN
#
#          priceByArea detailedType                         suggestedTexts  \
# 0              725.0          NaN                                    NaN
# typology         NaN         flat                                    NaN
# subtitle         NaN          NaN                   Avda. Elvas, Badajoz
# title            NaN          NaN  Flat in Calle Francisco Pedraja Muñoz
#
#          hasPlan  has3DTour  has360 topNewDevelopment
# 0          False      False   False             False
# typology     NaN        NaN     NaN               NaN
# subtitle     NaN        NaN     NaN               NaN
# title        NaN        NaN     NaN               NaN
#
# [4 rows x 33 columns]

# %%
df.index
# Out:
# Index([0, 'typology', 'subtitle', 'title'], dtype='object')

# %%
df = df.drop('typology', axis=0)
df = df.drop('subtitle', axis=0)
df = df.drop('title', axis=0)
df
# Out:
#   propertyCode                                          thumbnail  \
# 0     89460691  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor    price propertyType operation   size  \
# 0            392156        8.0     3  79000.0         flat      sale  109.0
#
#   exterior        ...         status  newDevelopment hasLift priceByArea  \
# 0    False        ...           good           False    True       725.0
#
#   detailedType suggestedTexts hasPlan  has3DTour  has360 topNewDevelopment
# 0          NaN            NaN   False      False   False             False
#
# [1 rows x 33 columns]

# %%
#df = df.drop(['propertyCode'], axis=1)

# axis = 0 FILA y axis = 1 COLUMNA
#df = df.drop('typology', axis=0)
df
# Out:
#   propertyCode                                          thumbnail  \
# 0     89460691  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor    price propertyType operation   size  \
# 0            392156        8.0     3  79000.0         flat      sale  109.0
#
#   exterior        ...         status  newDevelopment hasLift priceByArea  \
# 0    False        ...           good           False    True       725.0
#
#   detailedType suggestedTexts hasPlan  has3DTour  has360 topNewDevelopment
# 0          NaN            NaN   False      False   False             False
#
# [1 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'latitude', 'longitude', 'showAddress', 'url', 'distance',
#        'hasVideo', 'status', 'newDevelopment', 'hasLift', 'priceByArea',
#        'detailedType', 'suggestedTexts', 'hasPlan', 'has3DTour', 'has360',
#        'topNewDevelopment'],
#       dtype='object')

# %%
df = df.drop(df.columns[[2,2]], axis = 'columns') 
# cambiar [0,1] para borrar columnas necesarias
df
# Out:
#     size hasLift
# 0  109.0    True

# %%
df = df.drop(df.columns[[0,1]], axis = 'columns')
# Out:
#                                            thumbnail externalReference  \
# 0  https://img3.idealista.com/blur/WEB_LISTING/0/...          2F8E44D7
#
#    numPhotos floor propertyType operation  size exterior  rooms  bathrooms  \
# 0       10.0    bj         flat      sale  45.0     True    1.0        1.0
#
#    ... status newDevelopment hasLift priceByArea detailedType suggestedTexts  \
# 0  ...   good          False    True      2222.0          NaN            NaN
#
#    hasPlan  has3DTour has360 topNewDevelopment
# 0    False      False  False             False
#
# [1 rows x 32 columns]

# %%
ascensor = [col for col in df.columns if 'hasLift' in col]

# %%
my_list = df.columns.tolist()
#type(my_list)
#indice
#list(df.columns)

# %%
# Dejar el dataframe con 3 columnas, size, price y hasLift
# Poner en indice de df una entrada unica por piso > ej: referencia, propertycode

# flat, garage, office, etc
# Madrid, 30km, 50, price, desc
# Madrid, 30km, 50, pricedrop, desc
# Madrid, 30km, 50, ratioeurm2, desc

# ¿Cuáles son los pisos más baratos en Madrid? > por número de habitación, por zonas, etc
# ¿Cuáles son las bajas de precio mas importantes? > pisos, garajes, etc
# ¿Dónde está el peor/mejor ratioeurm2 de España? ciudad

# Plots
