# %%
#API Idealista

# %%
#1
import json
import datetime
import requests
from requests.auth import HTTPBasicAuth
import exceptions

# %%
#2
apikey = 'zv3u0zzhv10ojbnnrzm1rhc4rnxpjcv5' # APYKEY
secret = 'L4z1zpuu1LKH'
auth_url = "https://api.idealista.com/oauth/token"
api_base_url = "http://api.idealista.com/3.5/{country}/search"

# %%
auth = HTTPBasicAuth(apikey, secret)
headers = {'Content-Type': ('application/'
                            'x-www-form-urlencoded;charset=UTF-8')}
payload = {'grant_type': 'client_credentials',
           'scope': 'read'}
response = requests.post(auth_url,
                         headers=headers,
                         data=payload,
                         auth=auth)
response
# Out:
# <Response [200]>

# %%
json.loads(response.text)
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDYzMzk4OSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMjBlMThiOWEtNmQzYy00NWU2LTg0YTAtNmRmNmQ0NTYyYjJlIiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.Y-Rs6IcfnpXENX9Ml2D14lyvlmjcr0Q9YQrZftN_0Kc',
#  'expires_in': 43199,
#  'jti': '20e18b9a-6d3c-45e6-84a0-6df6d4562b2e',
#  'scope': 'read',
#  'token_type': 'bearer'}

# %%
type(response)
# Out:
# requests.models.Response

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
help(response)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
# ...

# %%
response_data = response.json()
print(response_data["access_token"])
response_data["access_token"]
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDYzMzk4OSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMjBlMThiOWEtNmQzYy00NWU2LTg0YTAtNmRmNmQ0NTYyYjJlIiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.Y-Rs6IcfnpXENX9Ml2D14lyvlmjcr0Q9YQrZftN_0Kc
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDYzMzk4OSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMjBlMThiOWEtNmQzYy00NWU2LTg0YTAtNmRmNmQ0NTYyYjJlIiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.Y-Rs6IcfnpXENX9Ml2D14lyvlmjcr0Q9YQrZftN_0Kc'

# %%
response_data.keys()
# Out:
# dict_keys(['access_token', 'token_type', 'expires_in', 'scope', 'jti'])

# %%
response_data['token_type']
# Out:
# 'bearer'

# %%
#3
#token = response_data['access_token'] # Descomentar cuando necesitas otro token
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDYzMzk4OSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMjBlMThiOWEtNmQzYy00NWU2LTg0YTAtNmRmNmQ0NTYyYjJlIiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.Y-Rs6IcfnpXENX9Ml2D14lyvlmjcr0Q9YQrZftN_0Kc'
token

# %%
seconds = datetime.timedelta(seconds=response_data['expires_in'])
# timedelta > incremento de tiempo 

#token_exp = (datetime.datetime.now() + seconds)

print("token: " + token + "\n")
print("seconds: " + str(seconds) + "\n")
# Out:
# token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU5MDYzMzk4OSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMjBlMThiOWEtNmQzYy00NWU2LTg0YTAtNmRmNmQ0NTYyYjJlIiwiY2xpZW50X2lkIjoienYzdTB6emh2MTBvamJubnJ6bTFyaGM0cm54cGpjdjUifQ.Y-Rs6IcfnpXENX9Ml2D14lyvlmjcr0Q9YQrZftN_0Kc
#
# seconds: 11:59:59

# %%
print("now() es: " + str(type(datetime.datetime.now())) + "\ny seconds es: " + str(type(seconds)))
# Out:
# now() es: <class 'datetime.datetime'>
# y seconds es: <class 'datetime.timedelta'>

# %%
# Información de datetime: https://medium.com/python-pandemonium/datetime-datetime-seconds-8c76c5ace3d2
ahora = datetime.datetime.now()
expires_in = seconds + ahora

print("datetime: " + str(expires_in))

seconds.total_seconds() #segundos disponibles de conexión
# Out:
# datetime: 2020-05-28 04:46:52.152957
# 43199.0

# %%
data = {'center': '41.394554,2.175153',
        'distance': 10000,
        'operation': 'sale',
        'propertyType': 'homes',
        'locale': 'en',
        'maxItems': 50,
        'order': 'publicationDate',
        'numPage': 0,                # change this number for each request
        'sort': 'desc'} 

data1 = {'center': '40.4378698,-3.8196219', # Madrid
        'distance': 10000, # 10km
        'operation': 'sale', # sale o rent
        'propertyType': 'homes', # homes, offices, premises, garages, bedrooms
        'locale': 'en', # es, it, pt, en, ca
        'maxItems': 50,
        'order': 'publicationDate',
        'numPage': 0,  # change this number for each request
        'sort': 'desc'} 
data
data1
# Out:
# {'center': '40.4378698,-3.8196219',
#  'distance': 10000,
#  'locale': 'en',
#  'maxItems': 50,
#  'numPage': 0,
#  'operation': 'sale',
#  'order': 'publicationDate',
#  'propertyType': 'homes',
#  'sort': 'desc'}

# %%
# "https://api.idealista.com/3.5/{country}/search"

# url = api_base_url.format(country = "es")
# url = api_base_url.format(country = "pt")
# url = api_base_url.format(country = "it")

url = "https://api.idealista.com/3.5/es/search"

headers = {'Authorization': 'Bearer ' + token}
response_post = requests.post(url,
                         headers=headers,
                         data=data1) # data = dictionario de datos/filtros
# response_post.json()

# %%
# Único código a ejecutar para nuevas búsquedas

response_post = requests.post(url,
                         headers=headers,
                         data=data1) # cambiar con diccionario de datos
response_post
# Out:
# <Response [200]>

# %%
response_post.json()
# Out:
# {'actualPage': 1,
#  'elementList': [{'address': 'Calle de la Hermandad',
#    'bathrooms': 1,
#    'country': 'es',
#    'detailedType': {'typology': 'flat'},
#    'distance': '9765',
#    'district': 'Carabanchel',
#    'exterior': True,
#    'externalReference': '2F8E44D7',
#    'floor': 'bj',
#    'has360': False,
#    'has3DTour': False,
#    'hasLift': True,
#    'hasPlan': False,
#    'hasVideo': False,
#    'latitude': 40.3835532,
#    'longitude': -3.728982,
#    'municipality': 'Madrid',
#    'neighborhood': 'Abrantes',
#    'newDevelopment': False,
#    'numPhotos': 10,
#    'operation': 'sale',
#    'price': 100000.0,
#    'priceByArea': 2222.0,
#    'propertyCode': '89685410',
#    'propertyType': 'flat',
#    'province': 'Madrid',
#    'rooms': 1,
#    'showAddress': False,
#    'size': 45.0,
#    'status': 'good',
#    'suggestedTexts': {'subtitle': 'Abrantes, Madrid',
#     'title': 'Flat in Calle de la Hermandad'},
# ...

# %%
# Pandas

# %%
import pandas as pd

# %%
type(response_post.json())
# Out:
# dict

# %%
values = my_dict.values()

# %%
my_dict = response_post.json()
keys = my_dict.keys()
keys
# Out:
# dict_keys(['elementList', 'total', 'totalPages', 'actualPage', 'itemsPerPage', 'numPaginations', 'hiddenResults', 'summary', 'paginable', 'upperRangePosition', 'lowerRangePosition'])

# %%
dict0 = my_dict['elementList'][0]
dict0.keys()
# Out:
# dict_keys(['propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor', 'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms', 'bathrooms', 'address', 'province', 'municipality', 'district', 'country', 'neighborhood', 'latitude', 'longitude', 'showAddress', 'url', 'distance', 'hasVideo', 'status', 'newDevelopment', 'hasLift', 'priceByArea', 'detailedType', 'suggestedTexts', 'hasPlan', 'has3DTour', 'has360', 'topNewDevelopment'])

# %%
dict0.values()
# Out:
# dict_values(['89685410', 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/2c/dd/72/774106315.jpg', '2F8E44D7', 10, 'bj', 100000.0, 'flat', 'sale', 45.0, True, 1, 1, 'Calle de la Hermandad', 'Madrid', 'Madrid', 'Carabanchel', 'es', 'Abrantes', 40.3835532, -3.728982, False, 'https://www.idealista.com/inmueble/89685410/', '9765', False, 'good', False, True, 2222.0, {'typology': 'flat'}, {'subtitle': 'Abrantes, Madrid', 'title': 'Flat in Calle de la Hermandad'}, False, False, False, False])

# %%
dict0['size']
# Out:
# 45.0

# %%
df = pd.DataFrame.from_dict(my_dict)
# Esto falla por diferencia de tamaños de arrays en diccionario

# %%
my_dict.items()
# Out:
# dict_items([('elementList', [{'propertyCode': '89683323', 'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/b9/e3/13/774062064.jpg', 'externalReference': 'V-783R', 'numPhotos': 23, 'floor': '1', 'price': 240000.0, 'propertyType': 'flat', 'operation': 'sale', 'size': 78.0, 'exterior': False, 'rooms': 5, 'bathrooms': 1, 'address': 'Calle de Sugranyes', 'province': 'Barcelona', 'municipality': 'Barcelona', 'district': 'Sants-Montjuïc', 'country': 'es', 'neighborhood': 'Sants - Badal', 'latitude': 41.3749767, 'longitude': 2.1311105, 'showAddress': False, 'url': 'https://www.idealista.com/inmueble/89683323/', 'distance': '4270', 'hasVideo': False, 'status': 'good', 'newDevelopment': False, 'priceByArea': 3077.0, 'detailedType': {'typology': 'flat'}, 'suggestedTexts': {'subtitle': 'Sants - Badal, Barcelona', 'title': 'Flat in Calle de Sugranyes'}, 'hasPlan': False, 'has3DTour': False, 'has360': False, 'topNewDevelopment': False}, {'propertyCode': '89683247'
# ...

# %%
pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in my_dict.items() ]))
# Out:
#                                           elementList    total  totalPages  \
# 0   {'propertyCode': '89683323', 'thumbnail': 'htt...  21205.0       425.0
# 1   {'propertyCode': '89683247', 'thumbnail': 'htt...      NaN         NaN
# 2   {'propertyCode': '89683193', 'thumbnail': 'htt...      NaN         NaN
# 3   {'propertyCode': '89683282', 'thumbnail': 'htt...      NaN         NaN
# 4   {'propertyCode': '89683274', 'thumbnail': 'htt...      NaN         NaN
# 5   {'propertyCode': '89683187', 'thumbnail': 'htt...      NaN         NaN
# 6   {'propertyCode': '89683089', 'thumbnail': 'htt...      NaN         NaN
# 7   {'propertyCode': '89406916', 'thumbnail': 'htt...      NaN         NaN
# 8   {'propertyCode': '89666799', 'thumbnail': 'htt...      NaN         NaN
# 9   {'propertyCode': '89683119', 'thumbnail': 'htt...      NaN         NaN
# 10  {'propertyCode': '89661958', 'thumbnail': 'htt...      NaN         NaN
# ...

# %%
dict0 = my_dict['elementList'][0]
df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in dict0.items() ]))
df
# size price hasLift
# Out:
#          propertyCode                                          thumbnail  \
# 0            89685410  https://img3.idealista.com/blur/WEB_LISTING/0/...
# subtitle          NaN                                                NaN
# title             NaN                                                NaN
# typology          NaN                                                NaN
#
#          externalReference  numPhotos floor     price propertyType operation  \
# 0                 2F8E44D7       10.0    bj  100000.0         flat      sale
# subtitle               NaN        NaN   NaN       NaN          NaN       NaN
# title                  NaN        NaN   NaN       NaN          NaN       NaN
# typology               NaN        NaN   NaN       NaN          NaN       NaN
#
#           size exterior  ...  status  newDevelopment hasLift priceByArea  \
# 0         45.0     True  ...    good           False    True      2222.0
# ...

# %%
df.index
# Out:
# Index([0, 'subtitle', 'title', 'typology'], dtype='object')

# %%
df = df.drop('typology', axis=0)
df = df.drop('subtitle', axis=0)
df = df.drop('title', axis=0)
df
# Out:
#   propertyCode                                          thumbnail  \
# 0     89685410  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor     price propertyType operation  size  \
# 0          2F8E44D7       10.0    bj  100000.0         flat      sale  45.0
#
#   exterior  ...  status  newDevelopment hasLift priceByArea detailedType  \
# 0     True  ...    good           False    True      2222.0          NaN
#
#   suggestedTexts hasPlan has3DTour  has360  topNewDevelopment
# 0            NaN   False     False   False              False
#
# [1 rows x 34 columns]

# %%
#df = df.drop(['propertyCode'], axis=1)

# axis = 0 FILA y axis = 1 COLUMNA
#df = df.drop('typology', axis=0)
df
# Out:
#   propertyCode                                          thumbnail  \
# 0     89685410  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor     price propertyType operation  size  \
# 0          2F8E44D7       10.0    bj  100000.0         flat      sale  45.0
#
#   exterior  ...  status  newDevelopment hasLift priceByArea detailedType  \
# 0     True  ...    good           False    True      2222.0          NaN
#
#   suggestedTexts hasPlan has3DTour  has360  topNewDevelopment
# 0            NaN   False     False   False              False
#
# [1 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'neighborhood', 'latitude', 'longitude', 'showAddress',
#        'url', 'distance', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
#        'priceByArea', 'detailedType', 'suggestedTexts', 'hasPlan', 'has3DTour',
#        'has360', 'topNewDevelopment'],
#       dtype='object')

# %%
df = df.drop(df.columns[[0,1]], axis = 'columns') 
# cambiar [0,1] para borrar columnas necesarias
df
# Out:
#   exterior  rooms  bathrooms                address province municipality  \
# 0     True    1.0        1.0  Calle de la Hermandad   Madrid       Madrid
#
#       district country neighborhood   latitude  ...  status newDevelopment  \
# 0  Carabanchel      es     Abrantes  40.383553  ...    good          False
#
#   hasLift priceByArea detailedType suggestedTexts hasPlan has3DTour  has360  \
# 0    True      2222.0          NaN            NaN   False     False   False
#
#   topNewDevelopment
# 0             False
#
# [1 rows x 25 columns]

# %%
df = df.drop(df.columns[[0,1]], axis = 'columns')
# Out:
#                                            thumbnail externalReference  \
# 0  https://img3.idealista.com/blur/WEB_LISTING/0/...          2F8E44D7
#
#    numPhotos floor propertyType operation  size exterior  rooms  bathrooms  \
# 0       10.0    bj         flat      sale  45.0     True    1.0        1.0
#
#    ... status newDevelopment hasLift priceByArea detailedType suggestedTexts  \
# 0  ...   good          False    True      2222.0          NaN            NaN
#
#    hasPlan  has3DTour has360 topNewDevelopment
# 0    False      False  False             False
#
# [1 rows x 32 columns]

# %%
ascensor = [col for col in df.columns if 'hasLift' in col]

# %%
my_list = df.columns.tolist()
#type(my_list)
#indice
#list(df.columns)

# %%
# Dejar el dataframe con 3 columnas, size, price y hasLift
# Poner en indice de df una entrada unica por piso > ej: referencia, propertycode

# flat, garage, office, etc
# Madrid, 30km, 50, price, desc
# Madrid, 30km, 50, pricedrop, desc
# Madrid, 30km, 50, ratioeurm2, desc

# ¿Cuáles son los pisos más baratos en Madrid? > por número de habitación, por zonas, etc
# ¿Cuáles son las bajas de precio mas importantes? > pisos, garajes, etc
# ¿Dónde está el peor/mejor ratioeurm2 de España? ciudad

# Plots
